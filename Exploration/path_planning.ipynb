# %%
import prior

dataset = prior.load_dataset("procthor-10k")
dataset
# Out:
# Fetching reference HEAD
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|██████████| 10000/10000 [00:00<00:00, 25760.78it/s]
# Loading val: 100%|██████████| 1000/1000 [00:00<00:00, 25389.10it/s]
# Loading test: 100%|██████████| 1000/1000 [00:00<00:00, 25582.67it/s]
# DatasetDict(
#     train=Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# ),
#     val=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=val
# ),
#     test=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=test
# )
# )

# %%
house = dataset["train"][0]
type(house), house.keys(), house
# Out:
# (dict,
#  dict_keys(['doors', 'metadata', 'objects', 'proceduralParameters', 'rooms', 'walls', 'windows']),
#  {'doors': [{'assetId': 'Doorway_6',
#     'id': 'door|1|2',
#     'openable': False,
#     'openness': 0,
#     'room0': 'room|2',
#     'room1': 'room|2',
#     'wall0': 'wall|2|5.99|3.99|5.99|5.99',
#     'wall1': 'wall|exterior|5.99|3.99|5.99|5.99',
#     'holePolygon': [{'x': 0.4987163812589276, 'y': 0, 'z': 0},
#      {'x': 1.5362947256040203, 'y': 2.1068506240844727, 'z': 0}],
#     'assetPosition': {'x': 1.016530884310268,
#      'y': 1.0534253120422363,
#      'z': 0}}],
#   'metadata': {'agent': {'horizon': 30,
#     'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#     'rotation': {'x': 0, 'y': 90, 'z': 0},
#     'standing': True},
#    'roomSpecId': 'kitchen',
#    'schema': '1.0.0',
#    'warnings': {},
#    'agentPoses': {'arm': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0},
#      'standing': True},
#     'default': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0},
#      'standing': True},
#     'locobot': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0}},
#     'stretch': {'horizon': 30,
#      'position': {'x': 3.5, 'y': 0.95, 'z': 2.0},
#      'rotation': {'x': 0, 'y': 90, 'z': 0},
#      'standing': True}}},
#   'objects': [{'assetId': 'Countertop_I_8x2',
#     'children': [{'assetId': 'Apple_24',
#       'id': 'Apple|surface|2|0',
#       'kinematic': False,
#       'position': {'x': 0.5637316703796387,
#        'y': 1.0042839050292969,
#        'z': 3.35530424118042},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Egg_23',
#       'id': 'Egg|surface|2|1',
#       'kinematic': False,
#       'position': {'x': 0.4870651662349701,
#        'y': 1.027331042289734,
#        'z': 3.6610817909240723},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Spray_Bottle_8',
#       'id': 'SprayBottle|surface|2|2',
#       'kinematic': False,
#       'position': {'x': 0.26057788729667664,
#        'y': 1.0662530660629272,
#        'z': 3.35606050491333},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Lettuce_19',
#       'id': 'Lettuce|surface|2|3',
#       'kinematic': False,
#       'position': {'x': 0.24332460761070251,
#        'y': 1.027500867843628,
#        'z': 2.745353937149048},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'RoboTHOR_salt_pepper_shaker_bnyd_salt_v',
#       'id': 'SaltShaker|surface|2|4',
#       'kinematic': False,
#       'position': {'x': 0.3334498405456543,
#        'y': 0.9904139041900635,
#        'z': 3.6610817909240723},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Kettle_1',
#       'id': 'Kettle|surface|2|5',
#       'kinematic': False,
#       'position': {'x': 0.41322192549705505,
#        'y': 1.0344257354736328,
#        'z': 3.0510385036468506},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Kettle_1',
#       'id': 'Kettle|surface|2|6',
#       'kinematic': False,
#       'position': {'x': 0.489982545375824,
#        'y': 1.0344257354736328,
#        'z': 2.44099497795105},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Tomato_5',
#       'id': 'Tomato|surface|2|7',
#       'kinematic': False,
#       'position': {'x': 0.2566889822483063,
#        'y': 0.9945104718208313,
#        'z': 1.8300145864486694},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Wine_Bottle_1',
#       'id': 'WineBottle|surface|2|8',
#       'kinematic': False,
#       'position': {'x': 0.25668901205062866,
#        'y': 1.153962779045105,
#        'z': 2.1359734535217285},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Potato_6',
#       'id': 'Potato|surface|2|9',
#       'kinematic': False,
#       'position': {'x': 0.1779242604970932,
#        'y': 0.9769210815429688,
#        'z': 2.1421523094177246},
#       'rotation': {'x': -0.0, 'y': 0.0, 'z': 0.0}},
#      {'assetId': 'Bowl_22',
#       'id': 'Bowl|surface|2|11',
#       'kinematic': False,
#       'position': {'x': 0.25668907165527344,
#        'y': 1.0366127967834473,
#        'z': 2.4409947395324707},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Pencil_3',
#       'id': 'Pencil|surface|2|13',
#       'kinematic': False,
#       'position': {'x': 0.49016278982162476,
#        'y': 0.9471948742866516,
#        'z': 2.1359729766845703},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Soap_Bottle_3',
#       'id': 'SoapBottle|surface|2|14',
#       'kinematic': False,
#       'position': {'x': 0.4905245304107666,
#        'y': 1.0601518154144287,
#        'z': 2.74601674079895},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Plate_11',
#       'id': 'Plate|surface|2|15',
#       'kinematic': False,
#       'position': {'x': 0.1796281784772873,
#        'y': 1.0026221752166748,
#        'z': 3.0511207580566406},
#       'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}},
#      {'assetId': 'Ladle_1',
#       'id': 'Ladle|surface|2|16',
#       'kinematic': False,
#       'position': {'x': 0.4116273522377014,
#        'y': 0.9665365219116211,
#        'z': 3.647871494293213},
#       'rotation': {'x': -0.0, 'y': 180.0, 'z': -0.0}},
#      {'assetId': 'Fork_1',
#       'id': 'Fork|surface|2|17',
#       'kinematic': False,
#       'position': {'x': 0.4102102816104889,
#        'y': 0.9532511234283447,
#        'z': 1.8531603813171387},
#       'rotation': {'x': -0.0, 'y': 180.0, 'z': -0.0}}],
#     'id': 'CounterTop|2|0',
#     'kinematic': True,
#     'position': {'x': 0.33027573823928835,
#      'y': 0.46873316168785095,
#      'z': 2.745277252197266},
#     'rotation': {'x': 0, 'y': 90, 'z': 0},
#     'material': None},
#    {'assetId': 'Fridge_19',
#     'children': [{'assetId': 'Lettuce_7',
#       'id': 'Lettuce|surface|2|10',
#       'kinematic': False,
#       'position': {'x': 5.091383457183838,
#        'y': 0.7108428478240967,
#        'z': 0.4495431184768677},
#       'rotation': {'x': -0.0, 'y': -0.00016733960364945233, 'z': 0.0}},
#      {'assetId': 'Potato_2',
#       'id': 'Potato|surface|2|12',
#       'kinematic': False,
#       'position': {'x': 5.086888313293457,
#        'y': 1.0534775257110596,
#        'z': 0.33588168025016785},
#       'rotation': {'x': -0.0, 'y': -0.00016733960364945233, 'z': 0.0}}],
#     'id': 'Fridge|2|1',
#     'kinematic': True,
#     'position': {'x': 5.394602856636048,
#      'y': 0.8955701589584351,
#      'z': 0.4535314679145813},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Houseplant_11',
#     'id': 'HousePlant|2|2|0',
#     'kinematic': False,
#     'position': {'x': 2.1638059884110636,
#      'y': 0.44735240936279297,
#      'z': 0.4040222594694701},
#     'rotation': {'x': 0, 'y': 42.941641543344474, 'z': 0},
#     'material': None},
#    {'assetId': 'bin_25',
#     'id': 'GarbageCan|2|3',
#     'kinematic': False,
#     'position': {'x': 7.7613059598207474,
#      'y': 0.2631477117538452,
#      'z': 2.213693920969963},
#     'rotation': {'x': 0, 'y': 270, 'z': 0},
#     'material': None},
#    {'assetId': 'GarbageBag_21_2',
#     'id': 'GarbageBag|2|4',
#     'kinematic': False,
#     'position': {'x': 4.173373784882576,
#      'y': 0.2789691686630249,
#      'z': 3.4191244414432314},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Photo_1V',
#     'id': 'Painting|2|5',
#     'kinematic': True,
#     'position': {'x': 0.8102974199756547,
#      'y': 1.4138685528004606,
#      'z': 0.020870485454797746},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Photo_2',
#     'id': 'Painting|2|6',
#     'kinematic': True,
#     'position': {'x': 7.959129514545203,
#      'y': 1.331527213957422,
#      'z': 4.839191256680811},
#     'rotation': {'x': 0, 'y': 270, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Painting_3V',
#     'id': 'Painting|2|7',
#     'kinematic': True,
#     'position': {'x': 3.0986902424464073,
#      'y': 1.7585664590494803,
#      'z': 0.020870485454797746},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None},
#    {'assetId': 'Wall_Decor_Photo_6',
#     'id': 'Painting|2|8',
#     'kinematic': True,
#     'position': {'x': 4.008591369226025,
#      'y': 1.6047140561531188,
#      'z': 0.020870485454797746},
#     'rotation': {'x': 0, 'y': 0, 'z': 0},
#     'material': None}],
#   'proceduralParameters': {'ceilingColor': {'b': 0.3058823529411765,
#     'g': 0.3843137254901961,
#     'r': 0.42745098039215684},
#    'ceilingMaterial': {'name': 'PureWhite',
#     'color': {'b': 0.3058823529411765,
#      'g': 0.3843137254901961,
#      'r': 0.42745098039215684}},
#    'floorColliderThickness': 1.0,
#    'lights': [{'id': 'DirectionalLight',
#      'indirectMultiplier': 1.0,
#      'intensity': 1,
#      'position': {'x': 0.84, 'y': 0.1855, 'z': -1.09},
#      'rgb': {'r': 1.0, 'g': 1.0, 'b': 1.0},
#      'rotation': {'x': 66, 'y': 75, 'z': 0},
#      'shadow': {'type': 'Soft',
#       'strength': 1,
#       'normalBias': 0,
#       'bias': 0,
#       'nearPlane': 0.2,
#       'resolution': 'FromQualitySettings'},
#      'type': 'directional'},
#     {'id': 'light_2',
#      'intensity': 0.45,
#      'position': {'x': 3.9899999999999998,
#       'y': 4.351928794929904,
#       'z': 2.49375},
#      'range': 15,
#      'rgb': {'r': 1.0, 'g': 0.855, 'b': 0.722},
#      'shadow': {'type': 'Soft',
#       'strength': 1,
#       'normalBias': 0,
#       'bias': 0.05,
#       'nearPlane': 0.2,
#       'resolution': 'FromQualitySettings'},
#      'type': 'point'}],
#    'receptacleHeight': 0.7,
#    'reflections': [],
#    'skyboxId': 'SkyAlbany'},
#   'rooms': [{'ceilings': [],
#     'children': [],
#     'floorMaterial': {'name': 'OrangeCabinet'},
#     'floorPolygon': [{'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 0.0}],
#     'id': 'room|2',
#     'roomType': 'Kitchen'}],
#   'walls': [{'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|0.00|0.00|0.00|3.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 3.99}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|0.00|3.99|5.99|3.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 3.99}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|3.99|5.99|5.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 5.985}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|5.99|7.98|5.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 5.985}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|7.98|2.00|7.98|5.99',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 1.995}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|2.00|7.98|2.00',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 1.995}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|5.99|0.00|5.99|2.00',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 0.0}],
#     'roomId': 'room|2'},
#    {'color': {'b': 0.27450980392156865,
#      'g': 0.25098039215686274,
#      'r': 0.3764705882352941},
#     'id': 'wall|2|0.00|0.00|5.99|0.00',
#     'material': {'name': 'PureWhite',
#      'color': {'b': 0.27450980392156865,
#       'g': 0.25098039215686274,
#       'r': 0.3764705882352941}},
#     'polygon': [{'x': 5.985, 'y': 0, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 0.0}],
#     'roomId': 'room|2'},
#    {'id': 'wall|exterior|0.00|0.00|5.99|0.00',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 0.0, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 0, 'z': 0.0}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|0.00|0.00|0.00|3.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 0.0, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 0.0, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 0, 'z': 0.0}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|0.00|3.99|5.99|3.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 0.0, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 3.99},
#      {'x': 0.0, 'y': 0, 'z': 3.99}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|5.99|7.98|5.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 7.98, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 0, 'z': 5.985}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|0.00|5.99|2.00',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 0.0},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 0.0},
#      {'x': 5.985, 'y': 0, 'z': 1.995}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|2.00|7.98|2.00',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 5.985, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 0, 'z': 1.995}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|5.99|3.99|5.99|5.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 5.985, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 5.985, 'y': 4.551928794929904, 'z': 3.99},
#      {'x': 5.985, 'y': 0, 'z': 5.985},
#      {'x': 5.985, 'y': 0, 'z': 3.99}],
#     'roomId': 'exterior'},
#    {'id': 'wall|exterior|7.98|2.00|7.98|5.99',
#     'material': {'name': 'LivingRoomFireplacebrickTex'},
#     'polygon': [{'x': 7.98, 'y': 4.551928794929904, 'z': 1.995},
#      {'x': 7.98, 'y': 4.551928794929904, 'z': 5.985},
#      {'x': 7.98, 'y': 0, 'z': 1.995},
#      {'x': 7.98, 'y': 0, 'z': 5.985}],
#     'roomId': 'exterior'}],
#   'windows': []})

# %%
from ai2thor.controller import Controller
house = dataset["train"][3]
controller = Controller(scene=house)

# %%
import ai2thor.controller
import numpy as np
import random
import time
from PIL import Image
import os

# Initialize ProcTHOR controller
controller = ai2thor.controller.Controller(scene=house)

# Step 1: Get all reachable positions
event = controller.step("GetReachablePositions")
print(event.metadata)
reachable_positions = event.metadata["actionReturn"]
print(f"Reachable positions: {len(reachable_positions)}")

# Helper: discretize position for coverage grid
def discretize(pos, cell_size=0.25):
    return (round(pos["x"]/cell_size), round(pos["z"]/cell_size))

reachable_set = {discretize(p) for p in reachable_positions}
visited = set()

# Step 2: Main exploration loop
coverage_history = []
step = 0
max_steps = 100

def get_agent_position():
    pos = controller.last_event.metadata["agent"]["position"]
    return discretize(pos)

def save_img(i, event):
    img = Image.fromarray(event.frame)
    img.save(f"data/images/frame_{i}.png")
    return i + 1

os.makedirs("data/images", exist_ok=True)

i = 0
for step in range(max_steps):
    pos = get_agent_position()
    visited.add(pos)

    # Compute coverage
    coverage = len(visited) / len(reachable_set)
    coverage_history.append(coverage)
    print(f"[Step {step}] Coverage: {coverage:.2%}")

    # Check if we’ve seen everything
    if coverage >= 0.99:
        print("✅ Full coverage achieved!")
        break

    # Pick nearest unvisited cell
    unvisited = [p for p in reachable_positions if discretize(p) not in visited]
    if not unvisited:
        print("No unvisited cells left.")
        break

    # Pick a random unvisited target (can replace with frontier-based planner)
    target = random.choice(unvisited)

    # Move toward it (teleport for simplicity — later replace with path planning)
    event = controller.step(
        action="TeleportFull",
        x=target["x"],
        y=target["y"],
        z=target["z"],
        rotation={"x": 0, "y": 0, "z": 0},
        horizon=0,
        standing=True
    )
    i = save_img(i, event)
    if not event.metadata["lastActionSuccess"]:
        continue
    
    for _ in range(3):
        event = controller.step(action="RotateRight", degrees=np.random.randint(180))
        i = save_img(i, event)


print(f"Exploration complete! Final coverage: {coverage:.2%}")

controller.stop()
# Out:
# {'objects': [{'name': 'Apple|surface|6|28', 'position': {'x': 7.9029083251953125, 'y': 0.9998068809509277, 'z': 6.220105171203613}, 'rotation': {'x': 0.0, 'y': 180.0, 'z': 0.0}, 'visible': False, 'isInteractable': False, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': True, 'isSliced': False, 'openable': False, 'isOpen': False, 'openness': 0.0, 'pickupable': True, 'isPickedUp': False, 'moveable': False, 'mass': 0.20000000298023224, 'salientMaterials': ['Food'], 'receptacleObjectIds': None, 'distance': 4.811234474182129, 'objectType': 'Apple', 'objectId': 'Apple|surface|6|28', 'assetId': 'Apple_15', 'parentReceptacles': ['CounterTop|6|0'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': {'cornerPoints': [[7.966617584228516, 1.0799448490142822, 6.283814430236816], [7.966617584228516, 1.0799448490142822, 6.15639591217041], [7.966617584228516, 0.9383823871612549, 6.283814430236816], [7.966617584228516, 0.9383823871612549, 6.15639591217041], [7.839199066162109, 1.0799448490142822, 6.283814430236816], [7.839199066162109, 1.0799448490142822, 6.15639591217041], [7.839199066162109, 0.9383823871612549, 6.283814430236816], [7.839199066162109, 0.9383823871612549, 6.15639591217041]], 'center': {'x': 7.9029083251953125, 'y': 1.0091636180877686, 'z': 6.220105171203613}, 'size': {'x': 0.12741851806640625, 'y': 0.14156246185302734, 'z': 0.12741851806640625}}, 'objectOrientedBoundingBox': {'cornerPoints': [[7.839199066162109, 0.9383823275566101, 6.15639591217041], [7.966617584228516, 0.9383823275566101, 6.15639591217041], [7.966617584228516, 0.9383823275566101, 6.283814430236816], [7.839199066162109, 0.9383823275566101, 6.283814430236816], [7.839199066162109, 1.0799448490142822, 6.15639591217041], [7.966617584228516, 1.0799448490142822, 6.15639591217041], [7.966617584228516, 1.0799448490142822, 6.283814430236816], [7.839199066162109, 1.0799448490142822, 6.283814430236816]]}}, {'name': 'BaseballBat|surface|4|3', 'position': {'x': 13.292658805847168, 'y': 1.0369977951049805, 'z': 6.018613338470459}, 'rotation': {'x': 21.61927604675293, 'y': 101.0096664428711, 'z': 23.92591667175293}, 'visible': False, 'isInteractable': False, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': False, 'isOpen': False, 'openness': 0.0, 'pickupable': True, 'isPickedUp': False, 'moveable': False, 'mass': 0.8999999761581421, 'salientMaterials': ['Metal'], 'receptacleObjectIds': None, 'distance': 10.095101356506348, 'objectType': 'BaseballBat', 'objectId': 'BaseballBat|surface|4|3', 'assetId': 'BaseballBat_4', 'parentReceptacles': ['Bed|4|0|0'], 'controlledObjects': None, 'isMoving': True, 'axisAlignedBoundingBox': {'cornerPoints': [[13.614287376403809, 1.6508924961090088, 6.293294906616211], [13.614287376403809, 1.6508924961090088, 5.882616996765137], [13.614287376403809, 0.7727317810058594, 6.293294906616211], [13.614287376403809, 0.7727317810058594, 5.882616996765137], [13.139174461364746, 1.6508924961090088, 6.293294906616211], [13.139174461364746, 1.6508924961090088, 5.882616996765137], [13.139174461364746, 0.7727317810058594, 6.293294906616211], [13.139174461364746, 0.7727317810058594, 5.882616996765137]], 'center': {'x': 13.376730918884277, 'y': 1.211812138557434, 'z': 6.087955951690674}, 'size': {'x': 0.4751129150390625, 'y': 0.8781607151031494, 'z':  ...
# Reachable positions: 1066
# [Step 0] Coverage: 0.09%
# [Step 1] Coverage: 0.19%
# [Step 2] Coverage: 0.28%
# [Step 3] Coverage: 0.38%
# [Step 4] Coverage: 0.47%
# [Step 5] Coverage: 0.56%
# [Step 6] Coverage: 0.66%
# [Step 7] Coverage: 0.75%
# [Step 8] Coverage: 0.84%
# [Step 9] Coverage: 0.94%
# [Step 10] Coverage: 1.03%
# [Step 11] Coverage: 1.13%
# [Step 12] Coverage: 1.22%
# [Step 13] Coverage: 1.31%
# [Step 14] Coverage: 1.41%
# [Step 15] Coverage: 1.50%
# [Step 16] Coverage: 1.59%
# [Step 17] Coverage: 1.69%
# [Step 18] Coverage: 1.78%
# [Step 19] Coverage: 1.88%
# [Step 20] Coverage: 1.97%
# [Step 21] Coverage: 2.06%
# [Step 22] Coverage: 2.16%
# [Step 23] Coverage: 2.25%
# [Step 24] Coverage: 2.35%
# [Step 25] Coverage: 2.44%
# [Step 26] Coverage: 2.53%
# [Step 27] Coverage: 2.63%
# [Step 28] Coverage: 2.72%
# [Step 29] Coverage: 2.81%
# [Step 30] Coverage: 2.91%
# [Step 31] Coverage: 3.00%
# [Step 32] Coverage: 3.10%
# [Step 33] Coverage: 3.19%
# [Step 34] Coverage: 3.28%
# [Step 35] Coverage: 3.38%
# [Step 36] Coverage: 3.47%
# [Step 37] Coverage: 3.56%
# [Step 38] Coverage: 3.66%
# [Step 39] Coverage: 3.75%
# [Step 40] Coverage: 3.85%
# [Step 41] Coverage: 3.94%
# [Step 42] Coverage: 4.03%
# [Step 43] Coverage: 4.13%
# [Step 44] Coverage: 4.22%
# [Step 45] Coverage: 4.32%
# [Step 46] Coverage: 4.41%
# [Step 47] Coverage: 4.50%
# [Step 48] Coverage: 4.60%
# [Step 49] Coverage: 4.69%
# [Step 50] Coverage: 4.78%
# [Step 51] Coverage: 4.88%
# [Step 52] Coverage: 4.97%
# [Step 53] Coverage: 5.07%
# [Step 54] Coverage: 5.16%
# [Step 55] Coverage: 5.25%
# [Step 56] Coverage: 5.35%
# [Step 57] Coverage: 5.44%
# [Step 58] Coverage: 5.53%
# [Step 59] Coverage: 5.63%
# [Step 60] Coverage: 5.72%
# [Step 61] Coverage: 5.82%
# [Step 62] Coverage: 5.91%
# [Step 63] Coverage: 6.00%
# [Step 64] Coverage: 6.10%
# [Step 65] Coverage: 6.19%
# [Step 66] Coverage: 6.29%
# [Step 67] Coverage: 6.38%
# [Step 68] Coverage: 6.47%
# [Step 69] Coverage: 6.57%
# [Step 70] Coverage: 6.66%
# [Step 71] Coverage: 6.75%
# [Step 72] Coverage: 6.85%
# [Step 73] Coverage: 6.94%
# [Step 74] Coverage: 7.04%
# [Step 75] Coverage: 7.13%
# [Step 76] Coverage: 7.22%
# [Step 77] Coverage: 7.32%
# [Step 78] Coverage: 7.41%
# [Step 79] Coverage: 7.50%
# [Step 80] Coverage: 7.60%
# [Step 81] Coverage: 7.69%
# [Step 82] Coverage: 7.79%
# [Step 83] Coverage: 7.88%
# [Step 84] Coverage: 7.97%
# [Step 85] Coverage: 8.07%
# [Step 86] Coverage: 8.16%
# [Step 87] Coverage: 8.26%
# [Step 88] Coverage: 8.35%
# [Step 89] Coverage: 8.44%
# [Step 90] Coverage: 8.54%
# [Step 91] Coverage: 8.63%
# [Step 92] Coverage: 8.72%
# [Step 93] Coverage: 8.82%
# [Step 94] Coverage: 8.91%
# [Step 95] Coverage: 9.01%
# [Step 96] Coverage: 9.10%
# [Step 97] Coverage: 9.19%
# [Step 98] Coverage: 9.29%
# [Step 99] Coverage: 9.38%
# Exploration complete! Final coverage: 9.38%

# %%
import numpy as np

np.random.randint(180)
# Out:
# 92
