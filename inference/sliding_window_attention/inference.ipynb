# %%
import prior

dataset = prior.load_dataset("procthor-10k")
dataset
# Out:
# Fetching reference HEAD
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|██████████| 10000/10000 [00:00<00:00, 20953.86it/s]
# Loading val: 100%|██████████| 1000/1000 [00:00<00:00, 21978.00it/s]
# Loading test: 100%|██████████| 1000/1000 [00:00<00:00, 21012.81it/s]
# DatasetDict(
#     train=Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# ),
#     val=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=val
# ),
#     test=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=test
# )
# )

# %%
from download_weights import download_weights

download_weights()
# Out:
# Downloading pca.resnet.pt...
# Downloading...
# From (original): https://drive.google.com/uc?id=1YopVInqfhNyRph2fWYt63XCwQGOrhC6s
# From (redirected): https://drive.google.com/uc?id=1YopVInqfhNyRph2fWYt63XCwQGOrhC6s&confirm=t&uuid=7a6209cf-aaf3-4306-a733-33a912e792b4
# To: /Users/viriyadhika/Documents/5.UofT/Courses/CSC2503H-ComputerVision/Project/NavAssistant/inference/sliding_window_attention/Exploration/weights/pca.resnet.pt
# 100%|██████████| 121M/121M [00:03<00:00, 30.7MB/s]
# Downloading cnn.pt...
# Downloading...
# From (original): https://drive.google.com/uc?id=1oYtnFqY5aetkEZnU3VBKV0TrPxpSvtay
# From (redirected): https://drive.google.com/uc?id=1oYtnFqY5aetkEZnU3VBKV0TrPxpSvtay&confirm=t&uuid=a36542b7-327c-4c1c-b86e-ded7954bc475
# To: /Users/viriyadhika/Documents/5.UofT/Courses/CSC2503H-ComputerVision/Project/NavAssistant/inference/sliding_window_attention/Exploration/weights/cnn.pt
# 100%|██████████| 304M/304M [00:09<00:00, 33.4MB/s]
# Downloading random_resnet.pt...
# Downloading...
# From (original): https://drive.google.com/uc?id=1U5CHXKyK8_rmvmWPGrdTgzOO-64aeh3e
# From (redirected): https://drive.google.com/uc?id=1U5CHXKyK8_rmvmWPGrdTgzOO-64aeh3e&confirm=t&uuid=28323e0f-6b39-48fe-acfc-8a28bf30b3f8
# To: /Users/viriyadhika/Documents/5.UofT/Courses/CSC2503H-ComputerVision/Project/NavAssistant/inference/sliding_window_attention/Exploration/weights/random_resnet.pt
# 100%|██████████| 121M/121M [00:03<00:00, 39.4MB/s]
# Downloading resnet_18.pt...
# Downloading...
# From (original): https://drive.google.com/uc?id=1VDG22YKJJEfcqCg0bi9u3uVYqC2DAxGB
# From (redirected): https://drive.google.com/uc?id=1VDG22YKJJEfcqCg0bi9u3uVYqC2DAxGB&confirm=t&uuid=f8a244b4-9f91-4df4-8b7c-d8c3c6091ede
# To: /Users/viriyadhika/Documents/5.UofT/Courses/CSC2503H-ComputerVision/Project/NavAssistant/inference/sliding_window_attention/Exploration/weights/resnet_18.pt
# 100%|██████████| 122M/122M [00:02<00:00, 41.7MB/s]
# done downloaded to 'Exploration/weights

# %%
from ai2thor.controller import Controller


house = dataset["train"][3]
controller = Controller(scene=house, snapToGrid=False, rotateStepDegrees=30)
event = controller.step("Pass")
spawn = event.metadata["agent"]["position"]

# %%
import matplotlib.pyplot as plt
event = controller.step("MoveAhead")
plt.imshow(event.frame)

# %%
from rl import PPO, ActorCritic, Env, RolloutBuffer, ClipEnv, CLIPNovelty, load_actor_critic
from models import LSTMActor, LSTMCritic, FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic
from cons import MINIBATCHES, EPISODE_STEPS, FEAT_DIM, NUM_ACTIONS, DEVICE
import matplotlib.pyplot as plt
import numpy as np
import torch

# %%
# After loading the scene and stepping once:
event = controller.step("Pass")

# Extract bounding box
bounds_meta = event.metadata.get("sceneBounds", None)
if bounds_meta is None:
    raise KeyError("sceneBounds metadata not found")

center = bounds_meta["center"]
size   = bounds_meta["size"]

xmin = center["x"] - size["x"] / 2
xmax = center["x"] + size["x"] / 2
zmin = center["z"] - size["z"] / 2
zmax = center["z"] + size["z"] / 2

x_center = center["x"]
z_center = center["z"]
house_size = max(size["x"], size["z"]) / 2   # or size["x"]/2 if you want

# %%
event = controller.step(
    action="AddThirdPartyCamera",
    position={"x": x_center, "y": 20.0, "z": z_center},
    rotation={"x": 90.0, "y": 0.0, "z": 0.0},
    orthographic=True,
    orthographicSize=house_size,
    fieldOfView=60,
    skyboxColor="black"
)

# %%
topdown = event.third_party_camera_frames[0]
plt.imshow(topdown)

# %%
from models import FrozenResNetEncoder
import torch
ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetEncoder(FEAT_DIM, device=DEVICE)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS)
critic = SlidingWindowTransformerCritic(FEAT_DIM)
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

# %%
from rl import load_actor_critic

load_actor_critic(clip_actor_critic, "random_resnet.pt", device=DEVICE)
# Out:
# [🔁] Actor-Critic checkpoint loaded from clip_actor_critic_checkpoint_long_training_100.pt

# %%
from rl import PPO, inference, inference_video_mp4, teleport


def get_distributions(ppo: PPO, obs_seq, actions_tensor, clip_actor_critic):
    logits, value = ppo.act_and_value(obs_seq, actions_tensor, clip_actor_critic)
    dist = torch.distributions.Categorical(logits=logits)
    # dist = torch.distributions.Categorical(probs=torch.tensor([0.5,0.25,0.25]))
    print(dist.probs)
    return dist


def get_trajectory(controller, position):
    event = controller.step("Pass")
    # Load the topdown image
    topdown = event.third_party_camera_frames[0]
    H, W = topdown.shape[0], topdown.shape[1]

    # positions is List[(x,z)]
    pos = np.array(position)  # shape (T, 2)
    xs = pos[:,0]
    zs = pos[:,1]

    # Convert meters -> pixels
    img_x = (xs - (x_center - house_size)) * (W / (2 * house_size))
    img_y = (zs - (z_center - house_size)) * (H / (2 * house_size))
    img_y = H - img_y
    return topdown, img_x, img_y

points = {
    "center_point": {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.0},
    "trapped": {'x': 5.6405439376831055, 'y': 0.9009993672370911, 'z': 7.591506481170654},
    "inside_room": {'x': 8.765543937683105, 'y': 0.9009993672370911, 'z': 6.941987037658691},
}
for i in range(4):
    for name, point in points.items():
        position = inference_video_mp4(get_distributions, controller, ppo=PPO(0.08), init_position=point, env=clip_env, actor_critic=clip_actor_critic, video_path=f"rollout{name}_{i}.mp4")
        topdown, img_x, img_y = get_trajectory(controller, position)
    
        plt.figure(figsize=(8,8))
        plt.imshow(topdown)
        plt.plot(img_x, img_y, color="blue", linewidth=2)
        plt.scatter(img_x[0], img_y[0], color="green", label="Start")
        plt.scatter(img_x[-1], img_y[-1], color="blue", label="End")
        plt.legend()
        plt.axis("off")
        plt.savefig(f"rollout{name}_{i}.png", bbox_inches='tight', pad_inches=0.1)
        plt.show()

# %%
controller.stop()

# %% [markdown]
# # PCA Head

# %%
from models import FrozenResNetPCAEncoder

ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetPCAEncoder(FEAT_DIM, torch.zeros(FEAT_DIM, 512), device=DEVICE)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS)
critic = SlidingWindowTransformerCritic(FEAT_DIM)
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

# %%
from rl import load_actor_critic

load_actor_critic(clip_actor_critic, "pca_resnet.pt", device=DEVICE)
# Out:
# [🔁] Actor-Critic checkpoint loaded from pca_resnet.pt

# %%
import numpy as np
import matplotlib.pyplot as plt
points = {
    "center_point": {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.0},
    "trapped": {'x': 5.6405439376831055, 'y': 0.9009993672370911, 'z': 7.591506481170654},
    "inside_room": {'x': 8.765543937683105, 'y': 0.9009993672370911, 'z': 6.941987037658691},
}

for i in range(4):
    for name, point in points.items():
        position = inference_video_mp4(get_distributions, controller, ppo=PPO(0.08), init_position=point, env=clip_env, actor_critic=clip_actor_critic, video_path=f"rollout{name}_{i}.mp4")
        topdown, img_x, img_y = get_trajectory(controller, position)

        plt.figure(figsize=(8,8))
        plt.imshow(topdown)
        plt.plot(img_x, img_y, color="blue", linewidth=2)
        plt.scatter(img_x[0], img_y[0], color="green", label="Start")
        plt.scatter(img_x[-1], img_y[-1], color="blue", label="End")
        plt.legend()
        plt.axis("off")
        plt.savefig(f"rollout{name}_{i}.png", bbox_inches='tight', pad_inches=0.1)
        plt.show()
