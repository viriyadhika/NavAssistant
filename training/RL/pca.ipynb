# %%
import prior

dataset = prior.load_dataset("procthor-10k")
dataset
# Out:
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|██████████| 10000/10000 [00:00<00:00, 11395.48it/s]
# Loading val: 100%|██████████| 1000/1000 [00:00<00:00, 11860.88it/s]
# Loading test: 100%|██████████| 1000/1000 [00:00<00:00, 12041.21it/s]
# DatasetDict(
#     train=Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# ),
#     val=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=val
# ),
#     test=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=test
# )
# )

# %%
from ai2thor.controller import Controller


house = dataset["train"][3]
controller = Controller(scene=house, snapToGrid=False, rotateStepDegrees=30)
event = controller.step("Pass")
spawn = event.metadata["agent"]["position"]
# Out:
# /home/juyuanli/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/ai2thor/platform.py:154: UserWarning: could not connect to X Display: 5, Can't connect to display ":5": b'Authorization required, but no authorization protocol specified\n'
#   warnings.warn(

# %%
from rl import PPO, CLIPNovelty, ClipEnv, ActorCritic
from models import FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic
from cons import FEAT_DIM, NUM_ACTIONS

ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetEncoder(project_to_out_dim=False)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS) # Not important
critic = SlidingWindowTransformerCritic(FEAT_DIM) # Not important
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

# %%
from rl import inference, teleport
import torch

def get_distribution(ppo, obs_seq, actions_seq, actor_critic):
    dist = torch.distributions.Categorical(probs=torch.tensor([0.5, 0.25, 0.25]))
    return dist

all_obs = []
for i in range(12):
    event = teleport(controller)
    init_pos = event.metadata["agent"]["position"]
    obs = inference(get_distribution=get_distribution, controller=controller, ppo=ppo, init_position=init_pos, env=clip_env, actor_critic=clip_actor_critic, plot=False, n=32)
    all_obs.append(torch.stack(obs, dim=0))

all_obs_tensor = torch.cat(all_obs, dim=0)

# %%
embedding = encoder(all_obs_tensor.unsqueeze(0)).squeeze(0)

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=FEAT_DIM)
pca.fit(embedding.detach().cpu().numpy())
W = pca.components_.astype(np.float32)

# %%
import torch
import matplotlib.pyplot as plt
from rl import save_actor_critic, Env, RolloutBuffer, MINIBATCHES, EPISODE_STEPS, DEVICE, teleport
import wandb
import numpy as np


def train(controller, name: str, ppo: PPO, env: Env, actor_critic: ActorCritic, total_updates=10):
    run = wandb.init(
        reinit="finish_previous",
        entity="viriyadhika1",
        project="cv-final-project",
        name=name,
        config={},
    )
    try:
        event = controller.step("Pass")  # prime
        rewards = []
        episode_rewards = []
        for upd in range(total_updates):
            buf = RolloutBuffer()
            for mb in range(MINIBATCHES):
                # collect episodes
                episode_seq = []
                episode_reward = 0
                actions_seq = []
                for t in range(1, EPISODE_STEPS + 1):
                    with torch.no_grad():
                        obs_t = ppo.obs_from_event(event)  # (C,H,W)
                        obs_t_encoded = actor_critic.actor_critic_encoder(obs_t.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)
                        obs_seq = torch.stack(episode_seq + [obs_t_encoded], dim=0).unsqueeze(0).to(device=DEVICE)

                    if len(actions_seq) == 0:
                        actions_seq.append(torch.randint(0, NUM_ACTIONS, (1, 1)).item())

                    actions_tensor = torch.tensor(actions_seq, dtype=torch.long, device=DEVICE).unsqueeze(0)
                    logits, value = ppo.act_and_value(obs_seq, actions_tensor, actor_critic)
                    dist = torch.distributions.Categorical(logits=logits)
                    action_idx = dist.sample()
                    logp = dist.log_prob(action_idx)

                    action_idx, logp = action_idx.item(), logp.item()
                    event, reward = env.step_env(controller, action_idx)
                    done = t == EPISODE_STEPS

                    # store one step
                    buf.add(obs_t_encoded, action_idx, logp, reward, value, done)
                    episode_seq.append(obs_t_encoded)
                    actions_seq.append(action_idx)

                    wandb.log({ "reward": reward })

                    episode_reward += reward / EPISODE_STEPS

                    # 50% chance of teleport
                    if done:
                        env.reset()
                        if np.random.rand() > 0.5:
                            event = teleport(controller)

                wandb.log({ "episode_reward": episode_reward })

            ppo.ppo_update(buf, actor_critic)
            if (upd + 1) % 10 == 0:
                save_actor_critic(actor_critic, f"data/{name}_{upd}.pt")
            save_actor_critic(actor_critic, f"data/{name}.pt")

            print(f"Update {upd+1}/{total_updates} — steps: {len(buf)}")
    finally:
        run.finish()

    return buf, rewards, episode_rewards

# %%
from rl import PPO, CLIPNovelty, ClipEnv, ActorCritic
from models import FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic
from cons import FEAT_DIM, NUM_ACTIONS
from models import FrozenResNetPCAEncoder
from cons import DEVICE


ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetPCAEncoder(FEAT_DIM, torch.from_numpy(W), device=DEVICE)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS)
critic = SlidingWindowTransformerCritic(FEAT_DIM)
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

# %%
train(controller, "pca_resnet", ppo, clip_env, clip_actor_critic, 100)
# Out:
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/juyuanli/Viri/NavAssistant/RL/wandb/run-20251125_052610-qa3mf9ba</code>
# Syncing run <strong><a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/qa3mf9ba' target="_blank">pca_resnet</a></strong> to <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a>
#  View run at <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/qa3mf9ba' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/qa3mf9ba</a>
# [PPO] Epoch 0: Loss=63.8529, Policy=0.0028, Value=127.8073
# [PPO] Epoch 10: Loss=58.0585, Policy=0.0342, Value=116.1520
# [PPO] Epoch 20: Loss=44.9031, Policy=0.0139, Value=89.8846
# [PPO] Epoch 30: Loss=39.3054, Policy=-0.0001, Value=78.7180
# Approx KL Learned: 0.014651771634817123
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 1/100 — steps: 4096
# [PPO] Epoch 0: Loss=87.4955, Policy=0.0033, Value=175.0931
# [PPO] Epoch 10: Loss=63.6732, Policy=0.0078, Value=127.4387
# [PPO] Epoch 20: Loss=52.0177, Policy=-0.0016, Value=104.1472
# [PPO] Epoch 30: Loss=46.9801, Policy=-0.0001, Value=94.0685
# Approx KL Learned: 0.005950332153588533
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 2/100 — steps: 4096
# [PPO] Epoch 0: Loss=77.9881, Policy=0.0018, Value=156.0811
# [PPO] Epoch 10: Loss=65.1128, Policy=0.0001, Value=130.3330
# [PPO] Epoch 20: Loss=58.1767, Policy=-0.0024, Value=116.4656
# [PPO] Epoch 30: Loss=53.0081, Policy=-0.0052, Value=106.1342
# Approx KL Learned: 0.010727271437644958
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 3/100 — steps: 4096
# [PPO] Epoch 0: Loss=91.2246, Policy=0.0035, Value=182.5493
# [PPO] Epoch 10: Loss=71.6771, Policy=0.0005, Value=143.4586
# [PPO] Epoch 20: Loss=63.2192, Policy=-0.0024, Value=126.5488
# [PPO] Epoch 30: Loss=57.8823, Policy=-0.0042, Value=115.8787
# Approx KL Learned: 0.0075394343584775925
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 4/100 — steps: 4096
# [PPO] Epoch 0: Loss=78.0474, Policy=0.0011, Value=156.1981
# [PPO] Epoch 10: Loss=61.0948, Policy=-0.0024, Value=122.2977
# [PPO] Epoch 20: Loss=52.9569, Policy=-0.0058, Value=106.0295
# [PPO] Epoch 30: Loss=54.4525, Policy=-0.0104, Value=109.0294
# Approx KL Learned: 0.009403692558407784
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 5/100 — steps: 4096
# [PPO] Epoch 0: Loss=98.8277, Policy=0.0020, Value=197.7552
# [PPO] Epoch 10: Loss=78.3788, Policy=-0.0016, Value=156.8616
# [PPO] Epoch 20: Loss=67.2770, Policy=-0.0057, Value=134.6672
# [PPO] Epoch 30: Loss=61.1771, Policy=-0.0067, Value=122.4689
# Approx KL Learned: 0.010296057909727097
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 6/100 — steps: 4096
# [PPO] Epoch 0: Loss=82.6137, Policy=0.0014, Value=165.3263
# [PPO] Epoch 10: Loss=62.8917, Policy=-0.0021, Value=125.8877
# [PPO] Epoch 20: Loss=49.3330, Policy=-0.0090, Value=98.7827
# [PPO] Epoch 30: Loss=43.0595, Policy=-0.0092, Value=86.2371
# Approx KL Learned: 0.01167417410761118
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 7/100 — steps: 4096
# [PPO] Epoch 0: Loss=90.2473, Policy=0.0025, Value=180.5892
# [PPO] Epoch 10: Loss=65.7133, Policy=-0.0034, Value=131.5297
# [PPO] Epoch 20: Loss=53.9106, Policy=-0.0029, Value=107.9249
# [PPO] Epoch 30: Loss=47.9734, Policy=-0.0091, Value=96.0625
# Approx KL Learned: 0.017979545518755913
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 8/100 — steps: 4096
# [PPO] Epoch 0: Loss=76.6759, Policy=0.0069, Value=153.4354
# [PPO] Epoch 10: Loss=64.6353, Policy=0.0007, Value=129.3648
# [PPO] Epoch 20: Loss=49.5980, Policy=0.0002, Value=99.2921
# [PPO] Epoch 30: Loss=50.1416, Policy=-0.0026, Value=100.3844
# Approx KL Learned: 0.015375063754618168
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 9/100 — steps: 4096
# [PPO] Epoch 0: Loss=77.5805, Policy=0.0029, Value=155.2503
# [PPO] Epoch 10: Loss=73.4225, Policy=-0.0008, Value=146.9404
# [PPO] Epoch 20: Loss=61.4862, Policy=-0.0054, Value=123.0760
# [PPO] Epoch 30: Loss=60.6062, Policy=-0.0005, Value=121.3066
# Approx KL Learned: 0.01701149344444275
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_9.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 10/100 — steps: 4096
# [PPO] Epoch 0: Loss=99.2528, Policy=0.0051, Value=198.5909
# [PPO] Epoch 10: Loss=79.1037, Policy=0.0030, Value=158.2937
# [PPO] Epoch 20: Loss=72.1001, Policy=0.0013, Value=144.2917
# [PPO] Epoch 30: Loss=65.5454, Policy=-0.0025, Value=131.1901
# Approx KL Learned: 0.022790661081671715
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 11/100 — steps: 4096
# [PPO] Epoch 0: Loss=96.8767, Policy=0.0063, Value=193.8290
# [PPO] Epoch 10: Loss=65.0154, Policy=0.0049, Value=130.1064
# [PPO] Epoch 20: Loss=51.9172, Policy=-0.0014, Value=103.9230
# [PPO] Epoch 30: Loss=40.5493, Policy=-0.0080, Value=81.2026
# Approx KL Learned: 0.018552612513303757
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 12/100 — steps: 4096
# [PPO] Epoch 0: Loss=76.0328, Policy=0.0018, Value=152.1526
# [PPO] Epoch 10: Loss=51.9258, Policy=-0.0026, Value=103.9454
# [PPO] Epoch 20: Loss=39.0174, Policy=-0.0104, Value=78.1424
# [PPO] Epoch 30: Loss=32.7500, Policy=-0.0167, Value=65.6211
# Approx KL Learned: 0.02960934117436409
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 13/100 — steps: 4096
# [PPO] Epoch 0: Loss=102.2430, Policy=0.0065, Value=204.5552
# [PPO] Epoch 10: Loss=59.8154, Policy=0.0030, Value=119.7076
# [PPO] Epoch 20: Loss=42.7037, Policy=-0.0084, Value=85.5063
# [PPO] Epoch 30: Loss=32.9131, Policy=-0.0033, Value=65.9189
# Approx KL Learned: 0.07622470706701279
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 14/100 — steps: 4096
# [PPO] Epoch 0: Loss=95.6388, Policy=0.0039, Value=191.3428
# [PPO] Epoch 10: Loss=80.6992, Policy=0.0011, Value=161.4673
# [PPO] Epoch 20: Loss=66.7270, Policy=0.0021, Value=133.5277
# [PPO] Epoch 30: Loss=58.7193, Policy=-0.0037, Value=117.5191
# Approx KL Learned: 0.01829652674496174
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 15/100 — steps: 4096
# [PPO] Epoch 0: Loss=100.8486, Policy=0.0023, Value=201.7649
# [PPO] Epoch 10: Loss=73.4000, Policy=-0.0039, Value=146.8820
# [PPO] Epoch 20: Loss=56.8948, Policy=-0.0140, Value=113.8905
# [PPO] Epoch 30: Loss=48.3537, Policy=-0.0203, Value=96.8201
# Approx KL Learned: 0.0382872112095356
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 16/100 — steps: 4096
# [PPO] Epoch 0: Loss=96.2872, Policy=0.0047, Value=192.6422
# [PPO] Epoch 10: Loss=64.5815, Policy=-0.0045, Value=129.2511
# [PPO] Epoch 20: Loss=52.4872, Policy=-0.0152, Value=105.0828
# [PPO] Epoch 30: Loss=45.2691, Policy=-0.0225, Value=90.6616
# Approx KL Learned: 0.05077669769525528
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 17/100 — steps: 4096
# [PPO] Epoch 0: Loss=105.7342, Policy=0.0066, Value=211.5282
# [PPO] Epoch 10: Loss=69.7975, Policy=-0.0022, Value=139.6731
# [PPO] Epoch 20: Loss=58.7272, Policy=-0.0107, Value=117.5486
# [PPO] Epoch 30: Loss=49.4131, Policy=-0.0150, Value=98.9308
# Approx KL Learned: 0.036551181226968765
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 18/100 — steps: 4096
# [PPO] Epoch 0: Loss=120.4528, Policy=0.0072, Value=240.9594
# [PPO] Epoch 10: Loss=79.0823, Policy=-0.0043, Value=158.2452
# [PPO] Epoch 20: Loss=67.1582, Policy=-0.0103, Value=134.4094
# [PPO] Epoch 30: Loss=61.6578, Policy=-0.0123, Value=123.4053
# Approx KL Learned: 0.04041973501443863
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 19/100 — steps: 4096
# [PPO] Epoch 0: Loss=129.1539, Policy=0.0045, Value=258.3871
# [PPO] Epoch 10: Loss=92.8334, Policy=0.0035, Value=185.7468
# [PPO] Epoch 20: Loss=78.5151, Policy=-0.0096, Value=157.1351
# [PPO] Epoch 30: Loss=71.8241, Policy=-0.0190, Value=143.7735
# Approx KL Learned: 0.021854080259799957
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_19.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 20/100 — steps: 4096
# [PPO] Epoch 0: Loss=87.5703, Policy=0.0094, Value=175.1743
# [PPO] Epoch 10: Loss=62.4562, Policy=-0.0015, Value=124.9781
# [PPO] Epoch 20: Loss=45.8909, Policy=-0.0128, Value=91.8683
# [PPO] Epoch 30: Loss=33.1700, Policy=-0.0234, Value=66.4464
# Approx KL Learned: 0.05379345268011093
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 21/100 — steps: 4096
# [PPO] Epoch 0: Loss=81.4006, Policy=0.0055, Value=162.8778
# [PPO] Epoch 10: Loss=52.7425, Policy=-0.0048, Value=105.5821
# [PPO] Epoch 20: Loss=42.6756, Policy=-0.0137, Value=85.4664
# [PPO] Epoch 30: Loss=36.8796, Policy=-0.0226, Value=73.8918
# Approx KL Learned: 0.032428596168756485
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 22/100 — steps: 4096
# [PPO] Epoch 0: Loss=128.4064, Policy=0.0071, Value=256.8605
# [PPO] Epoch 10: Loss=86.6505, Policy=0.0056, Value=173.3526
# [PPO] Epoch 20: Loss=62.0643, Policy=-0.0020, Value=124.1954
# [PPO] Epoch 30: Loss=50.8911, Policy=-0.0094, Value=101.8672
# Approx KL Learned: 0.046119339764118195
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 23/100 — steps: 4096
# [PPO] Epoch 0: Loss=77.8607, Policy=0.0080, Value=155.7817
# [PPO] Epoch 10: Loss=60.2121, Policy=-0.0075, Value=120.5150
# [PPO] Epoch 20: Loss=50.8952, Policy=-0.0158, Value=101.8974
# [PPO] Epoch 30: Loss=44.8604, Policy=-0.0220, Value=89.8400
# Approx KL Learned: 0.046325553208589554
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 24/100 — steps: 4096
# [PPO] Epoch 0: Loss=89.0182, Policy=0.0076, Value=178.0942
# [PPO] Epoch 10: Loss=62.0074, Policy=-0.0007, Value=124.0898
# [PPO] Epoch 20: Loss=48.9793, Policy=-0.0185, Value=98.0657
# [PPO] Epoch 30: Loss=41.8944, Policy=-0.0275, Value=83.9133
# Approx KL Learned: 0.04236581549048424
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 25/100 — steps: 4096
# [PPO] Epoch 0: Loss=187.2637, Policy=0.0054, Value=374.5515
# [PPO] Epoch 10: Loss=73.9366, Policy=0.0086, Value=147.8940
# [PPO] Epoch 20: Loss=45.5940, Policy=0.0039, Value=91.2178
# [PPO] Epoch 30: Loss=32.7549, Policy=-0.0083, Value=65.5675
# Approx KL Learned: 0.09887231886386871
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 26/100 — steps: 4096
# [PPO] Epoch 0: Loss=93.4269, Policy=0.0118, Value=186.8773
# [PPO] Epoch 10: Loss=56.2486, Policy=0.0265, Value=112.4940
# [PPO] Epoch 20: Loss=43.9364, Policy=0.0128, Value=87.9015
# [PPO] Epoch 30: Loss=30.8057, Policy=0.0650, Value=61.5120
# Approx KL Learned: 0.10193605720996857
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 27/100 — steps: 4096
# [PPO] Epoch 0: Loss=123.2654, Policy=0.0069, Value=246.5714
# [PPO] Epoch 10: Loss=77.2307, Policy=0.0039, Value=154.5107
# [PPO] Epoch 20: Loss=50.0426, Policy=-0.0075, Value=100.1626
# [PPO] Epoch 30: Loss=35.7164, Policy=-0.0207, Value=71.5349
# Approx KL Learned: 0.044316038489341736
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 28/100 — steps: 4096
# [PPO] Epoch 0: Loss=123.7067, Policy=0.0043, Value=247.4544
# [PPO] Epoch 10: Loss=74.8006, Policy=-0.0018, Value=149.6555
# [PPO] Epoch 20: Loss=49.8864, Policy=-0.0083, Value=99.8418
# [PPO] Epoch 30: Loss=30.3228, Policy=-0.0216, Value=60.7385
# Approx KL Learned: 0.050709374248981476
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 29/100 — steps: 4096
# [PPO] Epoch 0: Loss=104.4431, Policy=0.0067, Value=208.9286
# [PPO] Epoch 10: Loss=79.1219, Policy=0.0046, Value=158.2900
# [PPO] Epoch 20: Loss=60.3127, Policy=0.0023, Value=120.6796
# [PPO] Epoch 30: Loss=41.1906, Policy=-0.0074, Value=82.4554
# Approx KL Learned: 0.03191804885864258
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_29.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 30/100 — steps: 4096
# [PPO] Epoch 0: Loss=125.5729, Policy=0.0078, Value=251.1965
# [PPO] Epoch 10: Loss=82.0410, Policy=-0.0033, Value=164.1524
# [PPO] Epoch 20: Loss=66.4959, Policy=-0.0175, Value=133.0913
# [PPO] Epoch 30: Loss=55.6709, Policy=-0.0272, Value=111.4596
# Approx KL Learned: 0.05197542533278465
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 31/100 — steps: 4096
# [PPO] Epoch 0: Loss=107.2547, Policy=0.0064, Value=214.5630
# [PPO] Epoch 10: Loss=84.5363, Policy=-0.0000, Value=169.1377
# [PPO] Epoch 20: Loss=75.2765, Policy=-0.0092, Value=150.6366
# [PPO] Epoch 30: Loss=68.3290, Policy=-0.0203, Value=136.7629
# Approx KL Learned: 0.029934871941804886
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 32/100 — steps: 4096
# [PPO] Epoch 0: Loss=130.2239, Policy=0.0047, Value=260.4883
# [PPO] Epoch 10: Loss=82.6707, Policy=0.0052, Value=165.3808
# [PPO] Epoch 20: Loss=63.8916, Policy=-0.0061, Value=127.8501
# [PPO] Epoch 30: Loss=51.4514, Policy=-0.0202, Value=102.9969
# Approx KL Learned: 0.04570867493748665
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 33/100 — steps: 4096
# [PPO] Epoch 0: Loss=91.0570, Policy=0.0050, Value=182.1418
# [PPO] Epoch 10: Loss=51.3117, Policy=0.0029, Value=102.6541
# [PPO] Epoch 20: Loss=32.0972, Policy=-0.0085, Value=64.2506
# [PPO] Epoch 30: Loss=26.3696, Policy=0.0166, Value=52.7571
# Approx KL Learned: 0.08761217445135117
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 34/100 — steps: 4096
# [PPO] Epoch 0: Loss=110.6794, Policy=0.0062, Value=221.3995
# [PPO] Epoch 10: Loss=67.8944, Policy=0.0088, Value=135.8289
# [PPO] Epoch 20: Loss=52.4767, Policy=-0.0075, Value=105.0229
# [PPO] Epoch 30: Loss=41.0392, Policy=-0.0155, Value=82.1664
# Approx KL Learned: 0.04549418017268181
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 35/100 — steps: 4096
# [PPO] Epoch 0: Loss=89.1657, Policy=0.0072, Value=178.3644
# [PPO] Epoch 10: Loss=65.2637, Policy=0.0018, Value=130.5730
# [PPO] Epoch 20: Loss=51.5106, Policy=-0.0039, Value=103.0773
# [PPO] Epoch 30: Loss=42.9156, Policy=-0.0102, Value=85.9006
# Approx KL Learned: 0.03205113112926483
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 36/100 — steps: 4096
# [PPO] Epoch 0: Loss=49.0779, Policy=0.0048, Value=98.1832
# [PPO] Epoch 10: Loss=30.9568, Policy=-0.0005, Value=61.9499
# [PPO] Epoch 20: Loss=18.9531, Policy=-0.0064, Value=37.9557
# [PPO] Epoch 30: Loss=15.5720, Policy=-0.0136, Value=31.2105
# Approx KL Learned: 0.049514152109622955
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 37/100 — steps: 4096
# [PPO] Epoch 0: Loss=88.0375, Policy=0.0083, Value=176.1349
# [PPO] Epoch 10: Loss=55.0614, Policy=0.0000, Value=110.1975
# [PPO] Epoch 20: Loss=41.4761, Policy=-0.0165, Value=83.0612
# [PPO] Epoch 30: Loss=32.1230, Policy=-0.0304, Value=64.3806
# Approx KL Learned: 0.04976682737469673
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 38/100 — steps: 4096
# [PPO] Epoch 0: Loss=76.6608, Policy=0.0077, Value=153.3415
# [PPO] Epoch 10: Loss=41.3158, Policy=0.0093, Value=82.6466
# [PPO] Epoch 20: Loss=25.1698, Policy=-0.0043, Value=50.3845
# [PPO] Epoch 30: Loss=19.1132, Policy=-0.0158, Value=38.2970
# Approx KL Learned: 0.04492642730474472
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 39/100 — steps: 4096
# [PPO] Epoch 0: Loss=81.5337, Policy=0.0061, Value=163.1095
# [PPO] Epoch 10: Loss=38.6913, Policy=-0.0047, Value=77.4440
# [PPO] Epoch 20: Loss=27.5584, Policy=-0.0201, Value=55.2092
# [PPO] Epoch 30: Loss=22.6389, Policy=-0.0323, Value=45.3942
# Approx KL Learned: 0.051398955285549164
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_39.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 40/100 — steps: 4096
# [PPO] Epoch 0: Loss=90.9224, Policy=0.0041, Value=181.8751
# [PPO] Epoch 10: Loss=52.5056, Policy=0.0198, Value=105.0079
# [PPO] Epoch 20: Loss=35.4385, Policy=-0.0029, Value=70.9173
# [PPO] Epoch 30: Loss=27.5214, Policy=-0.0183, Value=55.1161
# Approx KL Learned: 0.04056877642869949
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 41/100 — steps: 4096
# [PPO] Epoch 0: Loss=105.7392, Policy=0.0046, Value=211.5039
# [PPO] Epoch 10: Loss=67.2948, Policy=0.0031, Value=134.6200
# [PPO] Epoch 20: Loss=43.7431, Policy=-0.0116, Value=87.5456
# [PPO] Epoch 30: Loss=30.9877, Policy=-0.0262, Value=62.0650
# Approx KL Learned: 0.04662264138460159
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 42/100 — steps: 4096
# [PPO] Epoch 0: Loss=39.4784, Policy=0.0059, Value=78.9724
# [PPO] Epoch 10: Loss=21.1671, Policy=0.0026, Value=42.3573
# [PPO] Epoch 20: Loss=16.3468, Policy=-0.0013, Value=32.7261
# [PPO] Epoch 30: Loss=13.8386, Policy=-0.0096, Value=27.7236
# Approx KL Learned: 0.06764759123325348
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 43/100 — steps: 4096
# [PPO] Epoch 0: Loss=74.4038, Policy=0.0111, Value=148.8300
# [PPO] Epoch 10: Loss=56.7771, Policy=0.0008, Value=113.5962
# [PPO] Epoch 20: Loss=48.2986, Policy=-0.0100, Value=96.6616
# [PPO] Epoch 30: Loss=43.0852, Policy=-0.0237, Value=86.2622
# Approx KL Learned: 0.0381840318441391
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 44/100 — steps: 4096
# [PPO] Epoch 0: Loss=48.5582, Policy=0.0035, Value=97.1368
# [PPO] Epoch 10: Loss=32.5451, Policy=-0.0011, Value=65.1199
# [PPO] Epoch 20: Loss=26.7498, Policy=-0.0174, Value=53.5633
# [PPO] Epoch 30: Loss=21.7597, Policy=-0.0302, Value=43.6138
# Approx KL Learned: 0.07692372798919678
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 45/100 — steps: 4096
# [PPO] Epoch 0: Loss=86.9058, Policy=0.0162, Value=173.8309
# [PPO] Epoch 10: Loss=50.6459, Policy=0.0013, Value=101.3386
# [PPO] Epoch 20: Loss=38.7837, Policy=-0.0208, Value=77.6609
# [PPO] Epoch 30: Loss=30.7693, Policy=-0.0351, Value=61.6613
# Approx KL Learned: 0.07665935903787613
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 46/100 — steps: 4096
# [PPO] Epoch 0: Loss=89.5035, Policy=0.0135, Value=179.0420
# [PPO] Epoch 10: Loss=59.8938, Policy=0.0029, Value=119.8422
# [PPO] Epoch 20: Loss=50.1313, Policy=-0.0085, Value=100.3406
# [PPO] Epoch 30: Loss=43.8124, Policy=-0.0165, Value=87.7172
# Approx KL Learned: 0.0504661425948143
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 47/100 — steps: 4096
# [PPO] Epoch 0: Loss=58.6101, Policy=0.0076, Value=117.2269
# [PPO] Epoch 10: Loss=21.1146, Policy=0.0019, Value=42.2453
# [PPO] Epoch 20: Loss=19.6789, Policy=0.0029, Value=39.3756
# [PPO] Epoch 30: Loss=14.6667, Policy=0.0298, Value=29.3068
# Approx KL Learned: 0.04022900015115738
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 48/100 — steps: 4096
# [PPO] Epoch 0: Loss=57.1839, Policy=0.0098, Value=114.3811
# [PPO] Epoch 10: Loss=47.8848, Policy=-0.0080, Value=95.8163
# [PPO] Epoch 20: Loss=39.7937, Policy=-0.0210, Value=79.6609
# [PPO] Epoch 30: Loss=34.6845, Policy=-0.0325, Value=69.4677
# Approx KL Learned: 0.058126747608184814
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 49/100 — steps: 4096
# [PPO] Epoch 0: Loss=59.7866, Policy=0.0065, Value=119.5989
# [PPO] Epoch 10: Loss=33.1719, Policy=-0.0061, Value=66.3923
# [PPO] Epoch 20: Loss=27.8114, Policy=-0.0100, Value=55.6813
# [PPO] Epoch 30: Loss=24.2273, Policy=-0.0231, Value=48.5376
# Approx KL Learned: 0.03256981074810028
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_49.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 50/100 — steps: 4096
# [PPO] Epoch 0: Loss=69.8080, Policy=0.0099, Value=139.6251
# [PPO] Epoch 10: Loss=47.4204, Policy=-0.0047, Value=94.8770
# [PPO] Epoch 20: Loss=34.8616, Policy=-0.0186, Value=69.7875
# [PPO] Epoch 30: Loss=29.8973, Policy=-0.0284, Value=59.8797
# Approx KL Learned: 0.03489891439676285
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 51/100 — steps: 4096
# [PPO] Epoch 0: Loss=45.4069, Policy=0.0082, Value=90.8323
# [PPO] Epoch 10: Loss=35.1925, Policy=-0.0053, Value=70.4310
# [PPO] Epoch 20: Loss=30.6286, Policy=-0.0209, Value=61.3342
# [PPO] Epoch 30: Loss=27.9185, Policy=-0.0332, Value=55.9385
# Approx KL Learned: 0.05083472281694412
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 52/100 — steps: 4096
# [PPO] Epoch 0: Loss=59.7677, Policy=0.0045, Value=119.5649
# [PPO] Epoch 10: Loss=50.8241, Policy=-0.0005, Value=101.6862
# [PPO] Epoch 20: Loss=45.5525, Policy=-0.0193, Value=91.1808
# [PPO] Epoch 30: Loss=37.6905, Policy=-0.0292, Value=75.4768
# Approx KL Learned: 0.052403420209884644
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 53/100 — steps: 4096
# [PPO] Epoch 0: Loss=64.4988, Policy=0.0055, Value=129.0099
# [PPO] Epoch 10: Loss=46.6166, Policy=-0.0019, Value=93.2611
# [PPO] Epoch 20: Loss=38.3584, Policy=-0.0139, Value=76.7696
# [PPO] Epoch 30: Loss=31.0786, Policy=-0.0237, Value=62.2306
# Approx KL Learned: 0.04133976995944977
# [✅] Actor-Critic checkpoint saved to data/pca_resnet.pt
# Update 54/100 — steps: 4096
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f4a45c47690>>
# Traceback (most recent call last):
#   File "/home/juyuanli/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# ...
# -> 1562 self._backend.interface.publish_partial_history(
#    1563     self,
#    1564     data,
#    1565     user_step=self._step,
#    1566     step=step,
#    1567     flush=commit,
#    1568     publish_step=not_using_tensorboard,
#    1569 )
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/interface/interface.py:716, in InterfaceBase.publish_partial_history(self, run, data, user_step, step, flush, publish_step)
#     714 if flush is not None:
#     715     partial_history.action.flush = flush
# --> 716 self._publish_partial_history(partial_history)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/interface/interface_shared.py:91, in InterfaceShared._publish_partial_history(self, partial_history)
#      87 def _publish_partial_history(
#      88     self, partial_history: pb.PartialHistoryRequest
#      89 ) -> None:
#      90     rec = self._make_request(partial_history=partial_history)
# ---> 91     self._publish(rec)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:136, in AsyncioManager.run(self, fn)
#     133 future = self._schedule(fn, daemon=False)
#     135 try:
# --> 136     return future.result()
#     138 except concurrent.futures.CancelledError:
#     139     raise RunCancelledError from None
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:181, in AsyncioManager.run_soon.<locals>.fn_wrap_exceptions()
#     179 async def fn_wrap_exceptions() -> None:
#     180     try:
# --> 181         await fn()
#     182     except Exception:
#     183         _logger.exception("Uncaught exception in run_soon callback.")
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)
#     389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:181, in AsyncioManager.run_soon.<locals>.fn_wrap_exceptions()
#     179 async def fn_wrap_exceptions() -> None:
#     180     try:
# --> 181         await fn()
#     182     except Exception:
#     183         _logger.exception("Uncaught exception in run_soon callback.")
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)
#     389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
#     [... skipping similar frames: ServiceClient._send_server_request at line 64 (64 times), StreamWriter.drain at line 380 (64 times), AsyncioManager.run_soon.<locals>.fn_wrap_exceptions at line 181 (64 times), ServiceClient.publish at line 38 (64 times)]
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:181, in AsyncioManager.run_soon.<locals>.fn_wrap_exceptions()
#     179 async def fn_wrap_exceptions() -> None:
#     180     try:
# --> 181         await fn()
#     182     except Exception:
#     183         _logger.exception("Uncaught exception in run_soon callback.")
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)
#     389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:219, in AsyncioManager._wrap(self, fn, daemon, name)
#     216     if name and (task := asyncio.current_task()):
#     217         task.set_name(name)
# --> 219     return await fn()
#     220 finally:
#     221     if not daemon:
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)
#     389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:181, in AsyncioManager.run_soon.<locals>.fn_wrap_exceptions()
#     179 async def fn_wrap_exceptions() -> None:
#     180     try:
# --> 181         await fn()
#     182     except Exception:
#     183         _logger.exception("Uncaught exception in run_soon callback.")
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)
#     389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:181, in AsyncioManager.run_soon.<locals>.fn_wrap_exceptions()
#     179 async def fn_wrap_exceptions() -> None:
#     180     try:
# --> 181         await fn()
#     182     except Exception:
#     183         _logger.exception("Uncaught exception in run_soon callback.")
#
#     [... skipping similar frames: ServiceClient._send_server_request at line 64 (89 times), StreamWriter.drain at line 380 (89 times), ServiceClient.publish at line 38 (89 times), AsyncioManager.run_soon.<locals>.fn_wrap_exceptions at line 181 (88 times)]
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/asyncio_manager.py:181, in AsyncioManager.run_soon.<locals>.fn_wrap_exceptions()
#     179 async def fn_wrap_exceptions() -> None:
#     180     try:
# --> 181         await fn()
#     182     except Exception:
#     183         _logger.exception("Uncaught exception in run_soon callback.")
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:38, in ServiceClient.publish(self, request)
#      36 async def publish(self, request: spb.ServerRequest) -> None:
#      37     """Send a request without waiting for a response."""
# ---> 38     await self._send_server_request(request)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/wandb/sdk/lib/service/service_client.py:64, in ServiceClient._send_server_request(self, request)
#      61 data = request.SerializeToString()
#      62 self._writer.write(data)
# ---> 64 await self._writer.drain()
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/streams.py:380, in StreamWriter.drain(self)
#     378     exc = self._reader.exception()
#     379     if exc is not None:
# --> 380         raise exc
#     381 if self._transport.is_closing():
#     382     # Wait for protocol.connection_lost() call
#     383     # Raise connection closing error if any,
#    (...)
#     389     # in a loop would never call connection_lost(), so it
#     390     # would not see an error when the socket is closed.
#     391     await sleep(0)
#
# File ~/miniconda3/envs/nav_assistant/lib/python3.11/asyncio/selector_events.py:1061, in _SelectorSocketTransport.write(self, data)
#    1058 if not self._buffer:
#    1059     # Optimization: try to send now.
#    1060     try:
# -> 1061         n = self._sock.send(data)
#    1062     except (BlockingIOError, InterruptedError):
#    1063         pass
#
# BrokenPipeError: [Errno 32] Broken pipe
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.
# WARNING:asyncio:socket.send() raised exception.

# %% [markdown]
# # Fine Tuning

# %%
from rl import load_actor_critic

load_actor_critic(clip_actor_critic, "data/pca_resnet.pt")
# Out:
# [🔁] Actor-Critic checkpoint loaded from data/pca_resnet.pt

# %%
for g in clip_actor_critic.optimizer.param_groups:
    g['lr'] = g['lr'] / 5

train(controller, "pca_resnet_fine_tune", ppo, clip_env, clip_actor_critic, 25)
# Out:
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/juyuanli/Viri/NavAssistant/RL/wandb/run-20251125_074014-v49phdod</code>
# Syncing run <strong><a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/v49phdod' target="_blank">pca_resnet_fine_tune</a></strong> to <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a>
#  View run at <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/v49phdod' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/v49phdod</a>
# [PPO] Epoch 0: Loss=140.6094, Policy=0.0125, Value=281.2484
# [PPO] Epoch 10: Loss=139.1055, Policy=0.0073, Value=278.2513
# [PPO] Epoch 20: Loss=137.5756, Policy=0.0172, Value=275.1718
# [PPO] Epoch 30: Loss=135.2380, Policy=0.0169, Value=270.4968
# Approx KL Learned: 0.019346196204423904
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 1/25 — steps: 4096
# [PPO] Epoch 0: Loss=81.7055, Policy=0.0111, Value=163.4269
# [PPO] Epoch 10: Loss=81.0130, Policy=0.0116, Value=162.0410
# [PPO] Epoch 20: Loss=81.0892, Policy=0.0103, Value=162.1962
# [PPO] Epoch 30: Loss=80.6467, Policy=0.0118, Value=161.3081
# Approx KL Learned: 0.018562152981758118
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 2/25 — steps: 4096
# [PPO] Epoch 0: Loss=65.4218, Policy=0.0119, Value=130.8434
# [PPO] Epoch 10: Loss=64.8348, Policy=0.0058, Value=129.6814
# [PPO] Epoch 20: Loss=64.3869, Policy=0.0111, Value=128.7751
# [PPO] Epoch 30: Loss=63.7150, Policy=0.0051, Value=127.4432
# Approx KL Learned: 0.013021303340792656
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 3/25 — steps: 4096
# [PPO] Epoch 0: Loss=57.6158, Policy=0.0071, Value=115.2472
# [PPO] Epoch 10: Loss=57.4965, Policy=0.0100, Value=115.0026
# [PPO] Epoch 20: Loss=56.2057, Policy=0.0083, Value=112.4249
# [PPO] Epoch 30: Loss=56.0289, Policy=0.0093, Value=112.0691
# Approx KL Learned: 0.008886624127626419
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 4/25 — steps: 4096
# [PPO] Epoch 0: Loss=59.1052, Policy=0.0070, Value=118.2161
# [PPO] Epoch 10: Loss=57.9652, Policy=0.0050, Value=115.9401
# [PPO] Epoch 20: Loss=57.0864, Policy=0.0099, Value=114.1726
# [PPO] Epoch 30: Loss=56.5594, Policy=0.0119, Value=113.1146
# Approx KL Learned: 0.010883844457566738
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 5/25 — steps: 4096
# [PPO] Epoch 0: Loss=41.6040, Policy=0.0040, Value=83.2194
# [PPO] Epoch 10: Loss=40.6302, Policy=0.0024, Value=81.2750
# [PPO] Epoch 20: Loss=40.1557, Policy=0.0073, Value=80.3162
# [PPO] Epoch 30: Loss=39.0280, Policy=0.0039, Value=78.0674
# Approx KL Learned: 0.008166203275322914
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 6/25 — steps: 4096
# [PPO] Epoch 0: Loss=54.6204, Policy=0.0117, Value=109.2401
# [PPO] Epoch 10: Loss=53.4960, Policy=0.0057, Value=107.0032
# [PPO] Epoch 20: Loss=53.1934, Policy=0.0060, Value=106.3976
# [PPO] Epoch 30: Loss=52.0788, Policy=0.0059, Value=104.1684
# Approx KL Learned: 0.010464627295732498
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 7/25 — steps: 4096
# [PPO] Epoch 0: Loss=36.5254, Policy=0.0124, Value=73.0483
# [PPO] Epoch 10: Loss=36.2819, Policy=0.0095, Value=72.5668
# [PPO] Epoch 20: Loss=35.7651, Policy=0.0112, Value=71.5304
# [PPO] Epoch 30: Loss=34.8943, Policy=0.0053, Value=69.8003
# Approx KL Learned: 0.010981995612382889
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 8/25 — steps: 4096
# [PPO] Epoch 0: Loss=31.3169, Policy=0.0068, Value=62.6385
# [PPO] Epoch 10: Loss=30.6393, Policy=0.0116, Value=61.2737
# [PPO] Epoch 20: Loss=29.6886, Policy=0.0053, Value=59.3850
# [PPO] Epoch 30: Loss=29.0241, Policy=0.0036, Value=58.0593
# Approx KL Learned: 0.009460724890232086
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 9/25 — steps: 4096
# [PPO] Epoch 0: Loss=58.6175, Policy=0.0094, Value=117.2458
# [PPO] Epoch 10: Loss=58.5260, Policy=0.0181, Value=117.0452
# [PPO] Epoch 20: Loss=58.5130, Policy=0.0128, Value=117.0300
# [PPO] Epoch 30: Loss=58.3549, Policy=0.0126, Value=116.7138
# Approx KL Learned: 0.013047576881945133
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_9.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 10/25 — steps: 4096
# [PPO] Epoch 0: Loss=72.1424, Policy=0.0108, Value=144.2974
# [PPO] Epoch 10: Loss=71.5980, Policy=0.0110, Value=143.2082
# [PPO] Epoch 20: Loss=71.8184, Policy=0.0085, Value=143.6539
# [PPO] Epoch 30: Loss=70.4902, Policy=0.0088, Value=140.9967
# Approx KL Learned: 0.012177396565675735
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 11/25 — steps: 4096
# [PPO] Epoch 0: Loss=57.2982, Policy=0.0088, Value=114.6063
# [PPO] Epoch 10: Loss=57.3636, Policy=0.0118, Value=114.7313
# [PPO] Epoch 20: Loss=57.3458, Policy=0.0091, Value=114.7010
# [PPO] Epoch 30: Loss=57.1557, Policy=0.0114, Value=114.3162
# Approx KL Learned: 0.0074308766052126884
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 12/25 — steps: 4096
# [PPO] Epoch 0: Loss=30.4278, Policy=0.0065, Value=60.8612
# [PPO] Epoch 10: Loss=30.0647, Policy=0.0071, Value=60.1340
# [PPO] Epoch 20: Loss=29.3220, Policy=0.0081, Value=58.6465
# [PPO] Epoch 30: Loss=28.5861, Policy=0.0053, Value=57.1802
# Approx KL Learned: 0.012213761918246746
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 13/25 — steps: 4096
# [PPO] Epoch 0: Loss=32.6271, Policy=0.0105, Value=65.2520
# [PPO] Epoch 10: Loss=31.8489, Policy=0.0121, Value=63.6923
# [PPO] Epoch 20: Loss=30.8998, Policy=0.0063, Value=61.8056
# [PPO] Epoch 30: Loss=30.2991, Policy=0.0070, Value=60.6031
# Approx KL Learned: 0.010357328690588474
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 14/25 — steps: 4096
# [PPO] Epoch 0: Loss=41.5546, Policy=0.0020, Value=83.1246
# [PPO] Epoch 10: Loss=40.7181, Policy=0.0007, Value=81.4541
# [PPO] Epoch 20: Loss=40.1372, Policy=0.0047, Value=80.2842
# [PPO] Epoch 30: Loss=38.9290, Policy=0.0027, Value=77.8717
# Approx KL Learned: 0.009294234216213226
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 15/25 — steps: 4096
# [PPO] Epoch 0: Loss=50.3831, Policy=0.0077, Value=100.7701
# [PPO] Epoch 10: Loss=50.3072, Policy=0.0072, Value=100.6193
# [PPO] Epoch 20: Loss=49.0799, Policy=0.0061, Value=98.1668
# [PPO] Epoch 30: Loss=48.1484, Policy=0.0041, Value=96.3080
# Approx KL Learned: 0.01239684596657753
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 16/25 — steps: 4096
# [PPO] Epoch 0: Loss=40.5127, Policy=0.0047, Value=81.0363
# [PPO] Epoch 10: Loss=40.0217, Policy=0.0049, Value=80.0537
# [PPO] Epoch 20: Loss=39.4615, Policy=0.0069, Value=78.9293
# [PPO] Epoch 30: Loss=38.5923, Policy=0.0076, Value=77.1898
# Approx KL Learned: 0.011014703661203384
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 17/25 — steps: 4096
# [PPO] Epoch 0: Loss=46.5550, Policy=0.0074, Value=93.1151
# [PPO] Epoch 10: Loss=45.4655, Policy=0.0057, Value=90.9392
# [PPO] Epoch 20: Loss=44.8104, Policy=0.0099, Value=89.6210
# [PPO] Epoch 30: Loss=44.0920, Policy=0.0061, Value=88.1915
# Approx KL Learned: 0.013083950616419315
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 18/25 — steps: 4096
# [PPO] Epoch 0: Loss=48.1262, Policy=0.0034, Value=96.2693
# [PPO] Epoch 10: Loss=47.4061, Policy=0.0061, Value=94.8238
# [PPO] Epoch 20: Loss=46.9328, Policy=0.0059, Value=93.8775
# [PPO] Epoch 30: Loss=46.9793, Policy=0.0024, Value=93.9774
# Approx KL Learned: 0.011923057958483696
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 19/25 — steps: 4096
# [PPO] Epoch 0: Loss=55.7800, Policy=0.0077, Value=111.5722
# [PPO] Epoch 10: Loss=55.4683, Policy=0.0066, Value=110.9508
# [PPO] Epoch 20: Loss=55.3810, Policy=0.0092, Value=110.7710
# [PPO] Epoch 30: Loss=54.9057, Policy=0.0069, Value=109.8253
# Approx KL Learned: 0.010993091389536858
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_19.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 20/25 — steps: 4096
# [PPO] Epoch 0: Loss=45.3049, Policy=0.0028, Value=90.6272
# [PPO] Epoch 10: Loss=45.1330, Policy=0.0036, Value=90.2818
# [PPO] Epoch 20: Loss=44.8859, Policy=0.0053, Value=89.7842
# [PPO] Epoch 30: Loss=44.3011, Policy=0.0025, Value=88.6203
# Approx KL Learned: 0.013363574631512165
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 21/25 — steps: 4096
# [PPO] Epoch 0: Loss=45.0607, Policy=0.0057, Value=90.1337
# [PPO] Epoch 10: Loss=44.7391, Policy=0.0055, Value=89.4909
# [PPO] Epoch 20: Loss=44.5292, Policy=0.0063, Value=89.0694
# [PPO] Epoch 30: Loss=43.8998, Policy=0.0057, Value=87.8119
# Approx KL Learned: 0.012629425153136253
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 22/25 — steps: 4096
# [PPO] Epoch 0: Loss=65.6913, Policy=0.0111, Value=131.3957
# [PPO] Epoch 10: Loss=65.7401, Policy=0.0134, Value=131.4886
# [PPO] Epoch 20: Loss=65.4832, Policy=0.0092, Value=130.9836
# [PPO] Epoch 30: Loss=64.7768, Policy=0.0124, Value=129.5644
# Approx KL Learned: 0.012728016823530197
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 23/25 — steps: 4096
# [PPO] Epoch 0: Loss=31.1879, Policy=0.0088, Value=62.3765
# [PPO] Epoch 10: Loss=31.4733, Policy=0.0051, Value=62.9545
# [PPO] Epoch 20: Loss=30.9658, Policy=0.0109, Value=61.9281
# [PPO] Epoch 30: Loss=30.2942, Policy=0.0068, Value=60.5932
# Approx KL Learned: 0.011094615794718266
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 24/25 — steps: 4096
# [PPO] Epoch 0: Loss=55.3814, Policy=0.0066, Value=110.7706
# [PPO] Epoch 10: Loss=54.3290, Policy=0.0076, Value=108.6637
# [PPO] Epoch 20: Loss=53.2671, Policy=0.0070, Value=106.5408
# [PPO] Epoch 30: Loss=53.1350, Policy=0.0032, Value=106.2844
# Approx KL Learned: 0.011638903990387917
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune.pt
# Update 25/25 — steps: 4096
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>▁▁▇██▇▇████████▅█▃███▇███▇▇████▆▇▃▆▂▇███</td></tr><tr><td>reward</td><td>▃▄▂▁▅▆▄▄▅▇▆▆▇▄▇▅▇▄▂▇▂▅▇▁▄▂▅▇▃▇▇▃▄▅▇▄▃▇▄█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>0.6717</td></tr><tr><td>reward</td><td>0.80101</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pca_resnet_fine_tune</strong> at: <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/v49phdod' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/v49phdod</a><br> View project at: <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251125_074014-v49phdod/logs</code>
# (<rl.RolloutBuffer at 0x7f067c45da90>, [], [])

# %%
controller.stop()

# %%
house = dataset["train"][8084]
controller = Controller(scene=house, snapToGrid=False, rotateStepDegrees=30)
event = controller.step("Pass")
spawn = event.metadata["agent"]["position"]
# Out:
# /home/juyuanli/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/ai2thor/platform.py:154: UserWarning: could not connect to X Display: 5, Can't connect to display ":5": b'Authorization required, but no authorization protocol specified\n'
#   warnings.warn(

# %%
from rl import PPO, CLIPNovelty, ClipEnv, ActorCritic
from models import FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic
from cons import FEAT_DIM, NUM_ACTIONS

ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetEncoder(project_to_out_dim=False)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS) # Not important
critic = SlidingWindowTransformerCritic(FEAT_DIM) # Not important
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

from rl import inference, teleport
import torch

def get_distribution(ppo, obs_seq, actions_seq, actor_critic):
    dist = torch.distributions.Categorical(probs=torch.tensor([0.5, 0.25, 0.25]))
    return dist

all_obs = []
for i in range(12):
    event = teleport(controller)
    init_pos = event.metadata["agent"]["position"]
    obs = inference(get_distribution=get_distribution, controller=controller, ppo=ppo, init_position=init_pos, env=clip_env, actor_critic=clip_actor_critic, plot=False, n=32)
    all_obs.append(torch.stack(obs, dim=0))

all_obs_tensor = torch.cat(all_obs, dim=0)

embedding = encoder(all_obs_tensor.unsqueeze(0)).squeeze(0)

from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=FEAT_DIM)
pca.fit(embedding.detach().cpu().numpy())
W = pca.components_.astype(np.float32)

# %%
from rl import PPO, CLIPNovelty, ClipEnv, ActorCritic
from models import FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic
from cons import FEAT_DIM, NUM_ACTIONS
from models import FrozenResNetPCAEncoder
from cons import DEVICE


ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetPCAEncoder(FEAT_DIM, torch.from_numpy(W), device=DEVICE)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS)
critic = SlidingWindowTransformerCritic(FEAT_DIM)
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

# %%
train(controller, "pca_resnet_8084", ppo, clip_env, clip_actor_critic, 50)
# Out:
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/juyuanli/Viri/NavAssistant/RL/wandb/run-20251125_083856-7eve1jrs</code>
# Syncing run <strong><a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/7eve1jrs' target="_blank">pca_resnet_8084</a></strong> to <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a>
#  View run at <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/7eve1jrs' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/7eve1jrs</a>
# [PPO] Epoch 0: Loss=60.9980, Policy=0.0048, Value=122.0869
# [PPO] Epoch 10: Loss=52.1532, Policy=0.0070, Value=104.3999
# [PPO] Epoch 20: Loss=44.2574, Policy=-0.0020, Value=88.6206
# [PPO] Epoch 30: Loss=37.2804, Policy=-0.0109, Value=74.6877
# Approx KL Learned: 0.022272253409028053
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 1/50 — steps: 4096
# [PPO] Epoch 0: Loss=67.2917, Policy=0.0030, Value=134.6823
# [PPO] Epoch 10: Loss=51.2293, Policy=-0.0003, Value=102.5662
# [PPO] Epoch 20: Loss=41.5690, Policy=-0.0042, Value=83.2524
# [PPO] Epoch 30: Loss=35.7544, Policy=-0.0063, Value=71.6274
# Approx KL Learned: 0.013274455443024635
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 2/50 — steps: 4096
# [PPO] Epoch 0: Loss=66.3476, Policy=0.0033, Value=132.7949
# [PPO] Epoch 10: Loss=49.3431, Policy=-0.0033, Value=98.8001
# [PPO] Epoch 20: Loss=40.4885, Policy=-0.0057, Value=81.0957
# [PPO] Epoch 30: Loss=34.9161, Policy=-0.0102, Value=69.9599
# Approx KL Learned: 0.015121893025934696
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 3/50 — steps: 4096
# [PPO] Epoch 0: Loss=69.2332, Policy=-0.0002, Value=138.5736
# [PPO] Epoch 10: Loss=56.8366, Policy=-0.0057, Value=113.7920
# [PPO] Epoch 20: Loss=47.0770, Policy=-0.0116, Value=94.2843
# [PPO] Epoch 30: Loss=40.4764, Policy=-0.0163, Value=81.0925
# Approx KL Learned: 0.022184377536177635
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 4/50 — steps: 4096
# [PPO] Epoch 0: Loss=62.4027, Policy=0.0031, Value=124.9056
# [PPO] Epoch 10: Loss=47.4544, Policy=-0.0018, Value=95.0186
# [PPO] Epoch 20: Loss=40.4994, Policy=-0.0050, Value=81.1144
# [PPO] Epoch 30: Loss=36.0312, Policy=-0.0087, Value=72.1860
# Approx KL Learned: 0.026093214750289917
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 5/50 — steps: 4096
# [PPO] Epoch 0: Loss=93.6714, Policy=0.0014, Value=187.4460
# [PPO] Epoch 10: Loss=77.5678, Policy=-0.0005, Value=155.2419
# [PPO] Epoch 20: Loss=66.1966, Policy=-0.0091, Value=132.5160
# [PPO] Epoch 30: Loss=59.9910, Policy=-0.0128, Value=120.1122
# Approx KL Learned: 0.01749390736222267
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 6/50 — steps: 4096
# [PPO] Epoch 0: Loss=82.8410, Policy=0.0055, Value=165.7764
# [PPO] Epoch 10: Loss=62.4248, Policy=-0.0023, Value=124.9578
# [PPO] Epoch 20: Loss=49.8083, Policy=-0.0048, Value=99.7288
# [PPO] Epoch 30: Loss=43.3004, Policy=-0.0103, Value=86.7250
# Approx KL Learned: 0.01226336881518364
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 7/50 — steps: 4096
# [PPO] Epoch 0: Loss=71.6783, Policy=0.0015, Value=143.4576
# [PPO] Epoch 10: Loss=53.4975, Policy=-0.0028, Value=107.1029
# [PPO] Epoch 20: Loss=45.7540, Policy=-0.0096, Value=91.6286
# [PPO] Epoch 30: Loss=39.1570, Policy=-0.0145, Value=78.4446
# Approx KL Learned: 0.026495497673749924
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 8/50 — steps: 4096
# [PPO] Epoch 0: Loss=69.2237, Policy=0.0036, Value=138.5417
# [PPO] Epoch 10: Loss=55.2447, Policy=-0.0024, Value=110.5936
# [PPO] Epoch 20: Loss=43.6724, Policy=0.0021, Value=87.4413
# [PPO] Epoch 30: Loss=37.1507, Policy=0.0451, Value=74.3080
# Approx KL Learned: 0.38995999097824097
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 9/50 — steps: 4096
# [PPO] Epoch 0: Loss=89.7817, Policy=0.0044, Value=179.6334
# [PPO] Epoch 10: Loss=49.4782, Policy=0.0041, Value=99.0258
# [PPO] Epoch 20: Loss=40.7094, Policy=-0.0048, Value=81.5069
# [PPO] Epoch 30: Loss=33.6678, Policy=-0.0102, Value=67.4365
# Approx KL Learned: 0.021046411246061325
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084_9.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 10/50 — steps: 4096
# [PPO] Epoch 0: Loss=58.0806, Policy=-0.0008, Value=116.2341
# [PPO] Epoch 10: Loss=48.8134, Policy=0.0063, Value=97.6865
# [PPO] Epoch 20: Loss=39.7790, Policy=-0.0069, Value=79.6418
# [PPO] Epoch 30: Loss=32.7956, Policy=0.0015, Value=65.6612
# Approx KL Learned: 0.01511814072728157
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 11/50 — steps: 4096
# [PPO] Epoch 0: Loss=59.7008, Policy=0.0012, Value=119.4762
# [PPO] Epoch 10: Loss=54.6888, Policy=-0.0008, Value=109.4527
# [PPO] Epoch 20: Loss=46.5254, Policy=-0.0081, Value=93.1414
# [PPO] Epoch 30: Loss=44.2544, Policy=-0.0131, Value=88.6099
# Approx KL Learned: 0.01487739384174347
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 12/50 — steps: 4096
# [PPO] Epoch 0: Loss=62.0557, Policy=0.0020, Value=124.1855
# [PPO] Epoch 10: Loss=57.2125, Policy=-0.0015, Value=114.5032
# [PPO] Epoch 20: Loss=43.5318, Policy=-0.0032, Value=87.1455
# [PPO] Epoch 30: Loss=45.9684, Policy=-0.0059, Value=92.0249
# Approx KL Learned: 0.012597031891345978
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 13/50 — steps: 4096
# [PPO] Epoch 0: Loss=55.0852, Policy=0.0030, Value=110.2388
# [PPO] Epoch 10: Loss=49.7358, Policy=-0.0011, Value=99.5467
# [PPO] Epoch 20: Loss=40.6661, Policy=-0.0027, Value=81.4117
# [PPO] Epoch 30: Loss=48.3483, Policy=-0.0058, Value=96.7825
# Approx KL Learned: 0.011537846177816391
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 14/50 — steps: 4096
# [PPO] Epoch 0: Loss=77.3270, Policy=0.0028, Value=154.7267
# [PPO] Epoch 10: Loss=64.2935, Policy=0.0004, Value=128.6644
# [PPO] Epoch 20: Loss=55.1308, Policy=-0.0045, Value=110.3497
# [PPO] Epoch 30: Loss=48.1571, Policy=-0.0106, Value=96.4142
# Approx KL Learned: 0.022163107991218567
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 15/50 — steps: 4096
# [PPO] Epoch 0: Loss=61.3185, Policy=0.0023, Value=122.7127
# [PPO] Epoch 10: Loss=45.1073, Policy=-0.0019, Value=90.2973
# [PPO] Epoch 20: Loss=35.8745, Policy=-0.0079, Value=71.8436
# [PPO] Epoch 30: Loss=31.6038, Policy=-0.0138, Value=63.3151
# Approx KL Learned: 0.024332981556653976
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 16/50 — steps: 4096
# [PPO] Epoch 0: Loss=71.6364, Policy=0.0032, Value=143.3334
# [PPO] Epoch 10: Loss=56.7921, Policy=-0.0048, Value=113.6639
# [PPO] Epoch 20: Loss=43.1981, Policy=-0.0091, Value=86.4866
# [PPO] Epoch 30: Loss=35.0483, Policy=-0.0141, Value=70.1958
# Approx KL Learned: 0.024954840540885925
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 17/50 — steps: 4096
# [PPO] Epoch 0: Loss=72.8429, Policy=0.0026, Value=145.7529
# [PPO] Epoch 10: Loss=33.9366, Policy=-0.0023, Value=67.9480
# [PPO] Epoch 20: Loss=29.1315, Policy=-0.0099, Value=58.3552
# [PPO] Epoch 30: Loss=27.0611, Policy=-0.0143, Value=54.2235
# Approx KL Learned: 0.03352636098861694
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 18/50 — steps: 4096
# [PPO] Epoch 0: Loss=63.6216, Policy=-0.0016, Value=127.3175
# [PPO] Epoch 10: Loss=49.9679, Policy=-0.0062, Value=100.0188
# [PPO] Epoch 20: Loss=37.5634, Policy=-0.0108, Value=75.2201
# [PPO] Epoch 30: Loss=30.7276, Policy=-0.0152, Value=61.5564
# Approx KL Learned: 0.022303888574242592
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 19/50 — steps: 4096
# [PPO] Epoch 0: Loss=85.6806, Policy=-0.0020, Value=171.4393
# [PPO] Epoch 10: Loss=43.7183, Policy=-0.0073, Value=87.5255
# [PPO] Epoch 20: Loss=29.1821, Policy=-0.0204, Value=58.4785
# [PPO] Epoch 30: Loss=23.2397, Policy=-0.0313, Value=46.6161
# Approx KL Learned: 0.05288045108318329
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084_19.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 20/50 — steps: 4096
# [PPO] Epoch 0: Loss=55.6298, Policy=0.0046, Value=111.3274
# [PPO] Epoch 10: Loss=39.4202, Policy=-0.0044, Value=78.9227
# [PPO] Epoch 20: Loss=26.1547, Policy=-0.0147, Value=52.4145
# [PPO] Epoch 30: Loss=22.0687, Policy=-0.0186, Value=44.2524
# Approx KL Learned: 0.03561761602759361
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 21/50 — steps: 4096
# [PPO] Epoch 0: Loss=58.6463, Policy=0.0066, Value=117.3605
# [PPO] Epoch 10: Loss=39.3472, Policy=-0.0065, Value=78.7866
# [PPO] Epoch 20: Loss=27.2747, Policy=-0.0131, Value=54.6559
# [PPO] Epoch 30: Loss=20.2027, Policy=0.0083, Value=40.4693
# Approx KL Learned: 0.031942691653966904
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 22/50 — steps: 4096
# [PPO] Epoch 0: Loss=60.6367, Policy=0.0035, Value=121.3510
# [PPO] Epoch 10: Loss=47.5223, Policy=0.0001, Value=95.1239
# [PPO] Epoch 20: Loss=39.3002, Policy=-0.0073, Value=78.6942
# [PPO] Epoch 30: Loss=41.6226, Policy=-0.0148, Value=83.3557
# Approx KL Learned: 0.016470694914460182
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 23/50 — steps: 4096
# [PPO] Epoch 0: Loss=78.2065, Policy=0.0059, Value=156.4742
# [PPO] Epoch 10: Loss=58.3549, Policy=-0.0043, Value=116.7893
# [PPO] Epoch 20: Loss=50.5310, Policy=-0.0124, Value=101.1570
# [PPO] Epoch 30: Loss=44.8101, Policy=-0.0192, Value=89.7282
# Approx KL Learned: 0.027885086834430695
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 24/50 — steps: 4096
# [PPO] Epoch 0: Loss=78.9132, Policy=0.0022, Value=157.9013
# [PPO] Epoch 10: Loss=67.2005, Policy=-0.0034, Value=134.4832
# [PPO] Epoch 20: Loss=54.3398, Policy=-0.0144, Value=108.7853
# [PPO] Epoch 30: Loss=45.1659, Policy=-0.0260, Value=90.4603
# Approx KL Learned: 0.030386995524168015
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 25/50 — steps: 4096
# [PPO] Epoch 0: Loss=82.8329, Policy=0.0061, Value=165.7272
# [PPO] Epoch 10: Loss=67.9718, Policy=-0.0045, Value=136.0242
# [PPO] Epoch 20: Loss=61.2420, Policy=-0.0152, Value=122.5843
# [PPO] Epoch 30: Loss=55.2681, Policy=-0.0269, Value=110.6596
# Approx KL Learned: 0.031446006149053574
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 26/50 — steps: 4096
# [PPO] Epoch 0: Loss=63.0514, Policy=0.0066, Value=126.1543
# [PPO] Epoch 10: Loss=40.8513, Policy=0.0010, Value=81.7616
# [PPO] Epoch 20: Loss=31.8944, Policy=-0.0081, Value=63.8668
# [PPO] Epoch 30: Loss=32.4948, Policy=0.0163, Value=65.0080
# Approx KL Learned: 0.2942400872707367
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 27/50 — steps: 4096
# [PPO] Epoch 0: Loss=62.2183, Policy=0.0046, Value=124.5065
# [PPO] Epoch 10: Loss=52.3798, Policy=0.0088, Value=104.8216
# [PPO] Epoch 20: Loss=45.1327, Policy=-0.0021, Value=90.3498
# [PPO] Epoch 30: Loss=40.5872, Policy=-0.0071, Value=81.2685
# Approx KL Learned: 0.02726244553923607
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 28/50 — steps: 4096
# [PPO] Epoch 0: Loss=70.9652, Policy=0.0025, Value=142.0024
# [PPO] Epoch 10: Loss=56.4506, Policy=-0.0085, Value=112.9935
# [PPO] Epoch 20: Loss=42.2571, Policy=-0.0138, Value=84.6152
# [PPO] Epoch 30: Loss=35.4581, Policy=-0.0223, Value=71.0359
# Approx KL Learned: 0.024352651089429855
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 29/50 — steps: 4096
# [PPO] Epoch 0: Loss=66.1335, Policy=0.0082, Value=132.3262
# [PPO] Epoch 10: Loss=51.1089, Policy=-0.0016, Value=102.2937
# [PPO] Epoch 20: Loss=38.1469, Policy=-0.0112, Value=76.3908
# [PPO] Epoch 30: Loss=31.2726, Policy=-0.0150, Value=62.6494
# Approx KL Learned: 0.03288523852825165
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084_29.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 30/50 — steps: 4096
# [PPO] Epoch 0: Loss=63.3489, Policy=0.0082, Value=126.7521
# [PPO] Epoch 10: Loss=39.3289, Policy=-0.0061, Value=78.7390
# [PPO] Epoch 20: Loss=26.3313, Policy=-0.0178, Value=52.7672
# [PPO] Epoch 30: Loss=19.1619, Policy=-0.0234, Value=38.4412
# Approx KL Learned: 0.03674246370792389
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 31/50 — steps: 4096
# [PPO] Epoch 0: Loss=49.2123, Policy=0.0102, Value=98.4700
# [PPO] Epoch 10: Loss=34.1652, Policy=-0.0003, Value=68.3951
# [PPO] Epoch 20: Loss=24.9298, Policy=-0.0111, Value=49.9470
# [PPO] Epoch 30: Loss=16.5765, Policy=-0.0204, Value=33.2597
# Approx KL Learned: 0.023588668555021286
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 32/50 — steps: 4096
# [PPO] Epoch 0: Loss=50.2887, Policy=0.0040, Value=100.6364
# [PPO] Epoch 10: Loss=37.7791, Policy=-0.0014, Value=75.6233
# [PPO] Epoch 20: Loss=24.6355, Policy=-0.0103, Value=49.3567
# [PPO] Epoch 30: Loss=16.8565, Policy=-0.0186, Value=33.8157
# Approx KL Learned: 0.03973318263888359
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 33/50 — steps: 4096
# [PPO] Epoch 0: Loss=58.1264, Policy=0.0067, Value=116.3095
# [PPO] Epoch 10: Loss=42.5317, Policy=-0.0014, Value=85.1350
# [PPO] Epoch 20: Loss=33.8814, Policy=-0.0027, Value=67.8400
# [PPO] Epoch 30: Loss=33.6017, Policy=-0.0231, Value=67.3191
# Approx KL Learned: 0.03619803488254547
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 34/50 — steps: 4096
# [PPO] Epoch 0: Loss=80.3546, Policy=0.0118, Value=160.7576
# [PPO] Epoch 10: Loss=70.3610, Policy=-0.0064, Value=140.8045
# [PPO] Epoch 20: Loss=63.5437, Policy=-0.0205, Value=127.1968
# [PPO] Epoch 30: Loss=56.5204, Policy=-0.0305, Value=113.1697
# Approx KL Learned: 0.05648443102836609
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 35/50 — steps: 4096
# [PPO] Epoch 0: Loss=43.1806, Policy=0.0075, Value=86.4137
# [PPO] Epoch 10: Loss=31.7172, Policy=0.0024, Value=63.4970
# [PPO] Epoch 20: Loss=23.4191, Policy=-0.0096, Value=46.9208
# [PPO] Epoch 30: Loss=19.2256, Policy=-0.0187, Value=38.5548
# Approx KL Learned: 0.04483563452959061
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 36/50 — steps: 4096
# [PPO] Epoch 0: Loss=58.8496, Policy=0.0093, Value=117.7521
# [PPO] Epoch 10: Loss=43.7172, Policy=0.0061, Value=87.4931
# [PPO] Epoch 20: Loss=36.5890, Policy=-0.0101, Value=73.2686
# [PPO] Epoch 30: Loss=31.8671, Policy=-0.0215, Value=63.8474
# Approx KL Learned: 0.041176553815603256
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 37/50 — steps: 4096
# [PPO] Epoch 0: Loss=61.6930, Policy=0.0102, Value=123.4292
# [PPO] Epoch 10: Loss=47.2154, Policy=-0.0028, Value=94.4978
# [PPO] Epoch 20: Loss=36.5661, Policy=-0.0145, Value=73.2214
# [PPO] Epoch 30: Loss=29.9289, Policy=-0.0240, Value=59.9677
# Approx KL Learned: 0.035974979400634766
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 38/50 — steps: 4096
# [PPO] Epoch 0: Loss=68.0291, Policy=0.0083, Value=136.0914
# [PPO] Epoch 10: Loss=41.2559, Policy=0.0017, Value=82.5606
# [PPO] Epoch 20: Loss=27.3735, Policy=-0.0137, Value=54.8252
# [PPO] Epoch 30: Loss=23.3141, Policy=-0.0195, Value=46.7172
# Approx KL Learned: 0.04387909173965454
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 39/50 — steps: 4096
# [PPO] Epoch 0: Loss=32.5196, Policy=0.0057, Value=65.0654
# [PPO] Epoch 10: Loss=21.9496, Policy=-0.0002, Value=43.9362
# [PPO] Epoch 20: Loss=20.2858, Policy=-0.0047, Value=40.6188
# [PPO] Epoch 30: Loss=13.3776, Policy=-0.0023, Value=26.7974
# Approx KL Learned: 0.08202488720417023
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084_39.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 40/50 — steps: 4096
# [PPO] Epoch 0: Loss=44.6915, Policy=0.0124, Value=89.3955
# [PPO] Epoch 10: Loss=29.8022, Policy=0.0068, Value=59.6212
# [PPO] Epoch 20: Loss=23.4956, Policy=-0.0035, Value=47.0394
# [PPO] Epoch 30: Loss=17.3566, Policy=-0.0133, Value=34.7804
# Approx KL Learned: 0.0939234122633934
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 41/50 — steps: 4096
# [PPO] Epoch 0: Loss=53.5239, Policy=0.0044, Value=107.0648
# [PPO] Epoch 10: Loss=34.9119, Policy=-0.0050, Value=69.8637
# [PPO] Epoch 20: Loss=28.7678, Policy=-0.0119, Value=57.5854
# [PPO] Epoch 30: Loss=25.3416, Policy=-0.0167, Value=50.7447
# Approx KL Learned: 0.0319051668047905
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 42/50 — steps: 4096
# [PPO] Epoch 0: Loss=34.7619, Policy=0.0022, Value=69.5524
# [PPO] Epoch 10: Loss=23.4401, Policy=-0.0001, Value=46.9102
# [PPO] Epoch 20: Loss=18.0482, Policy=-0.0127, Value=36.1566
# [PPO] Epoch 30: Loss=13.3602, Policy=-0.0173, Value=26.7939
# Approx KL Learned: 0.0696244090795517
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 43/50 — steps: 4096
# [PPO] Epoch 0: Loss=90.8163, Policy=0.0089, Value=181.6843
# [PPO] Epoch 10: Loss=39.6404, Policy=0.0147, Value=79.3182
# [PPO] Epoch 20: Loss=26.4043, Policy=-0.0037, Value=52.8839
# [PPO] Epoch 30: Loss=25.2328, Policy=-0.0188, Value=50.5697
# Approx KL Learned: 0.03888976573944092
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 44/50 — steps: 4096
# [PPO] Epoch 0: Loss=30.4198, Policy=0.0043, Value=60.8476
# [PPO] Epoch 10: Loss=12.5232, Policy=-0.0033, Value=25.0700
# [PPO] Epoch 20: Loss=9.4104, Policy=-0.0102, Value=18.8616
# [PPO] Epoch 30: Loss=6.8375, Policy=-0.0156, Value=13.7341
# Approx KL Learned: 0.08385054022073746
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 45/50 — steps: 4096
# [PPO] Epoch 0: Loss=73.1003, Policy=0.0100, Value=146.2354
# [PPO] Epoch 10: Loss=46.5503, Policy=0.0072, Value=93.1381
# [PPO] Epoch 20: Loss=31.7212, Policy=-0.0061, Value=63.5083
# [PPO] Epoch 30: Loss=22.3831, Policy=-0.0188, Value=44.8547
# Approx KL Learned: 0.0835927426815033
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 46/50 — steps: 4096
# [PPO] Epoch 0: Loss=64.4749, Policy=0.0076, Value=129.0002
# [PPO] Epoch 10: Loss=35.6236, Policy=0.0167, Value=71.2755
# [PPO] Epoch 20: Loss=25.0711, Policy=-0.0009, Value=50.2071
# [PPO] Epoch 30: Loss=18.8558, Policy=-0.0113, Value=37.7998
# Approx KL Learned: 0.0365801677107811
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 47/50 — steps: 4096
# [PPO] Epoch 0: Loss=48.8794, Policy=0.0094, Value=97.7996
# [PPO] Epoch 10: Loss=30.1552, Policy=0.0025, Value=60.3638
# [PPO] Epoch 20: Loss=25.9751, Policy=-0.0047, Value=52.0189
# [PPO] Epoch 30: Loss=22.1504, Policy=-0.0126, Value=44.3837
# Approx KL Learned: 0.028813324868679047
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 48/50 — steps: 4096
# [PPO] Epoch 0: Loss=72.3470, Policy=0.0081, Value=144.7555
# [PPO] Epoch 10: Loss=48.4258, Policy=-0.0016, Value=96.9321
# [PPO] Epoch 20: Loss=39.2872, Policy=-0.0154, Value=78.6808
# [PPO] Epoch 30: Loss=32.2496, Policy=-0.0275, Value=64.6286
# Approx KL Learned: 0.04050194472074509
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 49/50 — steps: 4096
# [PPO] Epoch 0: Loss=43.3490, Policy=0.0016, Value=86.7132
# [PPO] Epoch 10: Loss=26.6433, Policy=-0.0042, Value=53.3179
# [PPO] Epoch 20: Loss=12.0006, Policy=-0.0155, Value=24.0599
# [PPO] Epoch 30: Loss=8.9402, Policy=-0.0272, Value=17.9671
# Approx KL Learned: 0.12483619153499603
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084_49.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_8084.pt
# Update 50/50 — steps: 4096
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>▁▁▁▂▂▂▃▄▄▄▄▅▅▆▅▅▅▅▅▅▅▅▅▅▄▆▄▅▆▆▆▅▆▅▆▆▅▇▄█</td></tr><tr><td>reward</td><td>▁▃▁▄▂▃▂▄▃▃▅▃▁▃▇▃▅▁▂▇▄▂▃▅▅▇▆▇▆█▂▅▃▃▆▅▇▂▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>0.57813</td></tr><tr><td>reward</td><td>0.83237</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pca_resnet_8084</strong> at: <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/7eve1jrs' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/7eve1jrs</a><br> View project at: <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251125_083856-7eve1jrs/logs</code>
# (<rl.RolloutBuffer at 0x7effe9665b10>, [], [])

# %%
for g in clip_actor_critic.optimizer.param_groups:
    g['lr'] = g['lr'] / 5

train(controller, "pca_resnet_fine_tune_8084", ppo, clip_env, clip_actor_critic, 25)
# Out:
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/juyuanli/Viri/NavAssistant/RL/wandb/run-20251125_102747-23cadymg</code>
# Syncing run <strong><a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/23cadymg' target="_blank">pca_resnet_fine_tune_8084</a></strong> to <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a>
#  View run at <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/23cadymg' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/23cadymg</a>
# [PPO] Epoch 0: Loss=77.0599, Policy=0.0071, Value=154.1622
# [PPO] Epoch 10: Loss=55.6439, Policy=0.0103, Value=111.3223
# [PPO] Epoch 20: Loss=43.0944, Policy=0.0024, Value=86.2393
# [PPO] Epoch 30: Loss=35.5967, Policy=-0.0009, Value=71.2520
# Approx KL Learned: 0.022871196269989014
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 1/25 — steps: 4096
# [PPO] Epoch 0: Loss=171.2326, Policy=0.0075, Value=342.5032
# [PPO] Epoch 10: Loss=96.8148, Policy=0.0066, Value=193.6698
# [PPO] Epoch 20: Loss=69.7157, Policy=0.0027, Value=139.4819
# [PPO] Epoch 30: Loss=52.2602, Policy=0.0035, Value=104.5765
# Approx KL Learned: 0.03975043445825577
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 2/25 — steps: 4096
# [PPO] Epoch 0: Loss=42.9412, Policy=0.0064, Value=85.9063
# [PPO] Epoch 10: Loss=28.8299, Policy=0.0032, Value=57.6894
# [PPO] Epoch 20: Loss=18.7944, Policy=0.0012, Value=37.6231
# [PPO] Epoch 30: Loss=15.4073, Policy=-0.0062, Value=30.8649
# Approx KL Learned: 0.02500869520008564
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 3/25 — steps: 4096
# [PPO] Epoch 0: Loss=48.0780, Policy=0.0096, Value=96.1787
# [PPO] Epoch 10: Loss=37.1259, Policy=0.0057, Value=74.2831
# [PPO] Epoch 20: Loss=31.3326, Policy=-0.0023, Value=62.7107
# [PPO] Epoch 30: Loss=25.3635, Policy=-0.0061, Value=50.7802
# Approx KL Learned: 0.028040733188390732
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 4/25 — steps: 4096
# [PPO] Epoch 0: Loss=39.6179, Policy=0.0030, Value=79.2760
# [PPO] Epoch 10: Loss=27.9733, Policy=0.0024, Value=55.9872
# [PPO] Epoch 20: Loss=25.1164, Policy=-0.0048, Value=50.2884
# [PPO] Epoch 30: Loss=21.6062, Policy=-0.0102, Value=43.2780
# Approx KL Learned: 0.021844081580638885
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 5/25 — steps: 4096
# [PPO] Epoch 0: Loss=87.7908, Policy=0.0063, Value=175.6572
# [PPO] Epoch 10: Loss=59.5498, Policy=0.0019, Value=119.1843
# [PPO] Epoch 20: Loss=49.3715, Policy=-0.0020, Value=98.8323
# [PPO] Epoch 30: Loss=42.6934, Policy=-0.0072, Value=85.4868
# Approx KL Learned: 0.018118083477020264
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 6/25 — steps: 4096
# [PPO] Epoch 0: Loss=27.5193, Policy=0.0080, Value=55.0517
# [PPO] Epoch 10: Loss=18.6901, Policy=0.0038, Value=37.3999
# [PPO] Epoch 20: Loss=14.7038, Policy=0.0005, Value=29.4321
# [PPO] Epoch 30: Loss=12.2210, Policy=-0.0051, Value=24.4792
# Approx KL Learned: 0.017386313527822495
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 7/25 — steps: 4096
# [PPO] Epoch 0: Loss=29.4444, Policy=0.0052, Value=58.9186
# [PPO] Epoch 10: Loss=23.5927, Policy=0.0015, Value=47.2216
# [PPO] Epoch 20: Loss=21.0706, Policy=-0.0064, Value=42.1926
# [PPO] Epoch 30: Loss=19.3708, Policy=-0.0164, Value=38.8137
# Approx KL Learned: 0.027874654158949852
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 8/25 — steps: 4096
# [PPO] Epoch 0: Loss=19.4679, Policy=0.0097, Value=38.9530
# [PPO] Epoch 10: Loss=17.7308, Policy=0.0012, Value=35.4949
# [PPO] Epoch 20: Loss=16.6679, Policy=-0.0083, Value=33.3880
# [PPO] Epoch 30: Loss=15.8064, Policy=-0.0175, Value=31.6834
# Approx KL Learned: 0.029119880869984627
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 9/25 — steps: 4096
# [PPO] Epoch 0: Loss=20.2238, Policy=0.0087, Value=40.4487
# [PPO] Epoch 10: Loss=10.6773, Policy=-0.0010, Value=21.3759
# [PPO] Epoch 20: Loss=8.6430, Policy=-0.0039, Value=17.3139
# [PPO] Epoch 30: Loss=7.3952, Policy=-0.0086, Value=14.8288
# Approx KL Learned: 0.023712486028671265
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084_9.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 10/25 — steps: 4096
# [PPO] Epoch 0: Loss=43.9361, Policy=0.0119, Value=87.8915
# [PPO] Epoch 10: Loss=33.5889, Policy=0.0019, Value=67.2173
# [PPO] Epoch 20: Loss=29.5076, Policy=-0.0057, Value=59.0707
# [PPO] Epoch 30: Loss=26.0336, Policy=-0.0108, Value=52.1325
# Approx KL Learned: 0.028758913278579712
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 11/25 — steps: 4096
# [PPO] Epoch 0: Loss=27.7934, Policy=0.0138, Value=55.5825
# [PPO] Epoch 10: Loss=23.8146, Policy=0.0006, Value=47.6493
# [PPO] Epoch 20: Loss=21.9024, Policy=0.0010, Value=43.8243
# [PPO] Epoch 30: Loss=20.7911, Policy=-0.0054, Value=41.6155
# Approx KL Learned: 0.01991535723209381
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 12/25 — steps: 4096
# [PPO] Epoch 0: Loss=76.8093, Policy=0.0068, Value=153.6791
# [PPO] Epoch 10: Loss=59.4520, Policy=0.0034, Value=118.9694
# [PPO] Epoch 20: Loss=44.8333, Policy=0.0024, Value=89.7340
# [PPO] Epoch 30: Loss=37.5397, Policy=-0.0032, Value=75.1574
# Approx KL Learned: 0.022202059626579285
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 13/25 — steps: 4096
# [PPO] Epoch 0: Loss=34.0958, Policy=0.0055, Value=68.2336
# [PPO] Epoch 10: Loss=29.4168, Policy=-0.0018, Value=58.8888
# [PPO] Epoch 20: Loss=27.3111, Policy=-0.0040, Value=54.6821
# [PPO] Epoch 30: Loss=25.2703, Policy=-0.0102, Value=50.6137
# Approx KL Learned: 0.02873609960079193
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 14/25 — steps: 4096
# [PPO] Epoch 0: Loss=65.4410, Policy=0.0076, Value=130.9416
# [PPO] Epoch 10: Loss=55.9036, Policy=-0.0002, Value=111.8790
# [PPO] Epoch 20: Loss=49.3770, Policy=0.0003, Value=98.8268
# [PPO] Epoch 30: Loss=45.8398, Policy=-0.0012, Value=91.7552
# Approx KL Learned: 0.017645519226789474
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 15/25 — steps: 4096
# [PPO] Epoch 0: Loss=64.9166, Policy=0.0039, Value=129.8423
# [PPO] Epoch 10: Loss=38.6084, Policy=-0.0016, Value=77.2378
# [PPO] Epoch 20: Loss=24.6559, Policy=-0.0041, Value=49.3396
# [PPO] Epoch 30: Loss=14.3483, Policy=-0.0073, Value=28.7324
# Approx KL Learned: 0.023335792124271393
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 16/25 — steps: 4096
# [PPO] Epoch 0: Loss=31.7383, Policy=0.0054, Value=63.4891
# [PPO] Epoch 10: Loss=20.2834, Policy=0.0038, Value=40.5822
# [PPO] Epoch 20: Loss=17.1539, Policy=-0.0005, Value=34.3294
# [PPO] Epoch 30: Loss=14.1899, Policy=-0.0029, Value=28.4070
# Approx KL Learned: 0.009476518258452415
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 17/25 — steps: 4096
# [PPO] Epoch 0: Loss=21.7165, Policy=0.0022, Value=43.4518
# [PPO] Epoch 10: Loss=16.1389, Policy=0.0020, Value=32.2960
# [PPO] Epoch 20: Loss=12.6831, Policy=-0.0018, Value=25.3925
# [PPO] Epoch 30: Loss=11.0773, Policy=-0.0098, Value=22.1964
# Approx KL Learned: 0.01621856912970543
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 18/25 — steps: 4096
# [PPO] Epoch 0: Loss=28.6670, Policy=0.0041, Value=57.3654
# [PPO] Epoch 10: Loss=20.9437, Policy=-0.0021, Value=41.9298
# [PPO] Epoch 20: Loss=19.5127, Policy=-0.0101, Value=39.0821
# [PPO] Epoch 30: Loss=18.3060, Policy=-0.0147, Value=36.6779
# Approx KL Learned: 0.027529317885637283
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 19/25 — steps: 4096
# [PPO] Epoch 0: Loss=35.4246, Policy=0.0053, Value=70.8742
# [PPO] Epoch 10: Loss=32.7317, Policy=-0.0018, Value=65.5033
# [PPO] Epoch 20: Loss=30.6147, Policy=-0.0077, Value=61.2821
# [PPO] Epoch 30: Loss=29.3370, Policy=-0.0153, Value=58.7403
# Approx KL Learned: 0.023340754210948944
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084_19.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 20/25 — steps: 4096
# [PPO] Epoch 0: Loss=15.6686, Policy=0.0039, Value=31.3468
# [PPO] Epoch 10: Loss=7.4606, Policy=0.0031, Value=14.9321
# [PPO] Epoch 20: Loss=5.2603, Policy=-0.0033, Value=10.5443
# [PPO] Epoch 30: Loss=4.2723, Policy=-0.0088, Value=8.5804
# Approx KL Learned: 0.019739024341106415
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 21/25 — steps: 4096
# [PPO] Epoch 0: Loss=44.6467, Policy=0.0131, Value=89.3058
# [PPO] Epoch 10: Loss=33.1477, Policy=0.0033, Value=66.3265
# [PPO] Epoch 20: Loss=24.3035, Policy=-0.0006, Value=48.6463
# [PPO] Epoch 30: Loss=20.2295, Policy=-0.0073, Value=40.5118
# Approx KL Learned: 0.02975543960928917
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 22/25 — steps: 4096
# [PPO] Epoch 0: Loss=71.0169, Policy=0.0026, Value=142.1000
# [PPO] Epoch 10: Loss=55.3336, Policy=0.0017, Value=110.7329
# [PPO] Epoch 20: Loss=39.0747, Policy=-0.0020, Value=78.2217
# [PPO] Epoch 30: Loss=32.3609, Policy=-0.0079, Value=64.8062
# Approx KL Learned: 0.022606652230024338
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 23/25 — steps: 4096
# [PPO] Epoch 0: Loss=107.2902, Policy=0.0061, Value=214.6538
# [PPO] Epoch 10: Loss=68.5660, Policy=0.0025, Value=137.2106
# [PPO] Epoch 20: Loss=61.3440, Policy=-0.0048, Value=122.7786
# [PPO] Epoch 30: Loss=56.4785, Policy=-0.0066, Value=113.0501
# Approx KL Learned: 0.027718134224414825
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 24/25 — steps: 4096
# [PPO] Epoch 0: Loss=33.7363, Policy=0.0053, Value=67.5103
# [PPO] Epoch 10: Loss=28.2461, Policy=-0.0016, Value=56.5429
# [PPO] Epoch 20: Loss=24.0273, Policy=-0.0089, Value=48.1198
# [PPO] Epoch 30: Loss=20.6540, Policy=-0.0139, Value=41.3844
# Approx KL Learned: 0.028049172833561897
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_fine_tune_8084.pt
# Update 25/25 — steps: 4096
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>▆▁▇█▇▇▇▄▅▅█████████▄█▇▅███▇██████▇█▅▅▆▆█</td></tr><tr><td>reward</td><td>▃█▇▅▃▃▆▁▇▅▇▄▅▆▅▆▃▅▃▄▆▇▇▅▄▄▅▄▃▃▄▇▅▃▅▇▂▅▃▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>0.56152</td></tr><tr><td>reward</td><td>0.95571</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pca_resnet_fine_tune_8084</strong> at: <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/23cadymg' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/23cadymg</a><br> View project at: <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251125_102747-23cadymg/logs</code>
# (<rl.RolloutBuffer at 0x7effe9262910>, [], [])
