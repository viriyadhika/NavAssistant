# %%
import prior

dataset = prior.load_dataset("procthor-10k")
dataset
# Out:
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|██████████| 10000/10000 [00:00<00:00, 11426.81it/s]
# Loading val: 100%|██████████| 1000/1000 [00:00<00:00, 11946.49it/s]
# Loading test: 100%|██████████| 1000/1000 [00:00<00:00, 12035.69it/s]
# DatasetDict(
#     train=Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# ),
#     val=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=val
# ),
#     test=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=test
# )
# )

# %%
from ai2thor.controller import Controller


house = dataset["train"][3]
controller = Controller(scene=house, snapToGrid=False, rotateStepDegrees=30)
event = controller.step("Pass")
spawn = event.metadata["agent"]["position"]
# Out:
# /home/juyuanli/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/ai2thor/platform.py:154: UserWarning: could not connect to X Display: 5, Can't connect to display ":5": b'Authorization required, but no authorization protocol specified\n'
#   warnings.warn(

# %%
from rl import PPO, CLIPNovelty, ClipEnv, ActorCritic
from models import FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic
from cons import FEAT_DIM, NUM_ACTIONS

ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetEncoder(project_to_out_dim=False)
actor = SlidingWindowTransformerActor(FEAT_DIM, NUM_ACTIONS) # Not important
critic = SlidingWindowTransformerCritic(FEAT_DIM) # Not important
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)

# %%
from rl import inference, teleport
import torch

def get_distribution(ppo, obs_seq, actions_seq, actor_critic):
    dist = torch.distributions.Categorical(probs=torch.tensor([0.5, 0.25, 0.25]))
    return dist

all_obs = []
for i in range(12):
    event = teleport(controller)
    init_pos = event.metadata["agent"]["position"]
    obs = inference(get_distribution=get_distribution, controller=controller, ppo=ppo, init_position=init_pos, env=clip_env, actor_critic=clip_actor_critic, plot=False, n=32)
    all_obs.append(torch.stack(obs, dim=0))

all_obs_tensor = torch.cat(all_obs, dim=0)

# %%
embedding = encoder(all_obs_tensor.unsqueeze(0)).squeeze(0)

# %%
from sklearn.decomposition import PCA
import numpy as np

pca = PCA(n_components=FEAT_DIM)
pca.fit(embedding.detach().cpu().numpy())
W = pca.components_.astype(np.float32)

# %%
import torch
import matplotlib.pyplot as plt
from rl import save_actor_critic, Env, RolloutBuffer, MINIBATCHES, EPISODE_STEPS, DEVICE, teleport
import wandb
import numpy as np


def train(controller, name: str, ppo: PPO, env: Env, actor_critic: ActorCritic, total_updates=10):
    run = wandb.init(
        reinit="finish_previous",
        entity="viriyadhika1",
        project="cv-final-project",
        name=name,
        config={},
    )
    try:
        event = controller.step("Pass")  # prime
        rewards = []
        episode_rewards = []
        for upd in range(total_updates):
            buf = RolloutBuffer()
            for mb in range(MINIBATCHES):
                # collect episodes
                episode_seq = []
                episode_reward = 0
                actions_seq = []
                for t in range(1, EPISODE_STEPS + 1):
                    with torch.no_grad():
                        obs_t = ppo.obs_from_event(event)  # (C,H,W)
                        obs_t_encoded = actor_critic.actor_critic_encoder(obs_t.unsqueeze(0).unsqueeze(0)).squeeze(0).squeeze(0)
                        obs_seq = torch.stack(episode_seq + [obs_t_encoded], dim=0).unsqueeze(0).to(device=DEVICE)

                    if len(actions_seq) == 0:
                        actions_seq.append(torch.randint(0, NUM_ACTIONS, (1, 1)).item())

                    actions_tensor = torch.tensor(actions_seq, dtype=torch.long, device=DEVICE).unsqueeze(0)
                    logits, value = ppo.act_and_value(obs_seq, actions_tensor, actor_critic)
                    dist = torch.distributions.Categorical(logits=logits)
                    action_idx = dist.sample()
                    logp = dist.log_prob(action_idx)

                    action_idx, logp = action_idx.item(), logp.item()
                    event, reward = env.step_env(controller, action_idx)
                    done = t == EPISODE_STEPS

                    # store one step
                    buf.add(obs_t_encoded, action_idx, logp, reward, value, done)
                    episode_seq.append(obs_t_encoded)
                    actions_seq.append(action_idx)

                    wandb.log({ "reward": reward })

                    episode_reward += reward / EPISODE_STEPS

                    # 50% chance of teleport
                    if done:
                        env.reset()
                        if np.random.rand() > 0.5:
                            event = teleport(controller)

                wandb.log({ "episode_reward": episode_reward })

            ppo.ppo_update(buf, actor_critic)
            if (upd + 1) % 10 == 0:
                save_actor_critic(actor_critic, f"data/{name}_{upd}.pt")
            save_actor_critic(actor_critic, f"data/{name}.pt")

            print(f"Update {upd+1}/{total_updates} — steps: {len(buf)}")
    finally:
        run.finish()

    return buf, rewards, episode_rewards

# %%
from rl import PPO, CLIPNovelty, ClipEnv, ActorCritic
from models import FrozenResNetEncoder, SlidingWindowTransformerActor, SlidingWindowTransformerCritic, SharedSlidingWindowTransformer, SharedSlidingWindowTransformerActor, SharedSlidingWindowTransformerCritic
from cons import FEAT_DIM, NUM_ACTIONS
from models import FrozenResNetPCAEncoder
from cons import DEVICE


ENTROPY_COEF = 0.05

ppo = PPO(ENTROPY_COEF)
encoder = FrozenResNetPCAEncoder(FEAT_DIM, torch.from_numpy(W), device=DEVICE)
shared_transformer = SharedSlidingWindowTransformer(FEAT_DIM)
actor = SharedSlidingWindowTransformerActor(shared_transformer, NUM_ACTIONS)
critic = SharedSlidingWindowTransformerCritic(shared_transformer)
clip_novelty = CLIPNovelty()
clip_env = ClipEnv(clip_novelty)
clip_actor_critic = ActorCritic(encoder, actor, critic)
# Out:
# /home/juyuanli/miniconda3/envs/nav_assistant/lib/python3.11/site-packages/torch/_compile.py:53: UserWarning: optimizer contains a parameter group with duplicate parameters; in future, this will cause an error; see github.com/pytorch/pytorch/issues/40967 for more information
#   return disable_fn(*args, **kwargs)

# %%
for g in clip_actor_critic.optimizer.param_groups:
    g['lr'] = g['lr'] / 5

train(controller, "pca_resnet_sliding", ppo, clip_env, clip_actor_critic, 50)
# Out:
# wandb: Currently logged in as: viriyadhika-putra (viriyadhika1) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/juyuanli/Viri/NavAssistant/RL/wandb/run-20251125_182752-ar37e0m0</code>
# Syncing run <strong><a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/ar37e0m0' target="_blank">pca_resnet_sliding</a></strong> to <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a>
#  View run at <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/ar37e0m0' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/ar37e0m0</a>
# [PPO] Epoch 0: Loss=58.4037, Policy=0.0034, Value=116.8984
# [PPO] Epoch 10: Loss=56.7700, Policy=-0.0022, Value=113.6458
# [PPO] Epoch 20: Loss=54.4545, Policy=-0.0009, Value=109.0107
# [PPO] Epoch 30: Loss=51.2327, Policy=0.0044, Value=102.5559
# Approx KL Learned: 0.029724422842264175
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 1/50 — steps: 4096
# [PPO] Epoch 0: Loss=99.2506, Policy=0.0084, Value=198.5851
# [PPO] Epoch 10: Loss=87.5421, Policy=0.0148, Value=175.1565
# [PPO] Epoch 20: Loss=79.4512, Policy=0.0248, Value=158.9555
# [PPO] Epoch 30: Loss=73.8698, Policy=0.0211, Value=147.8006
# Approx KL Learned: 0.03531384468078613
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 2/50 — steps: 4096
# [PPO] Epoch 0: Loss=93.5240, Policy=0.0105, Value=187.1255
# [PPO] Epoch 10: Loss=85.8113, Policy=0.0116, Value=171.6992
# [PPO] Epoch 20: Loss=79.7406, Policy=0.0136, Value=159.5551
# [PPO] Epoch 30: Loss=75.6026, Policy=0.0131, Value=151.2810
# Approx KL Learned: 0.026324449107050896
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 3/50 — steps: 4096
# [PPO] Epoch 0: Loss=80.4844, Policy=0.0099, Value=161.0525
# [PPO] Epoch 10: Loss=76.4267, Policy=0.0093, Value=152.9389
# [PPO] Epoch 20: Loss=72.9950, Policy=0.0094, Value=146.0759
# [PPO] Epoch 30: Loss=70.7579, Policy=0.0068, Value=141.6067
# Approx KL Learned: 0.020742319524288177
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 4/50 — steps: 4096
# [PPO] Epoch 0: Loss=91.5911, Policy=0.0144, Value=183.2583
# [PPO] Epoch 10: Loss=87.9878, Policy=0.0151, Value=176.0505
# [PPO] Epoch 20: Loss=83.4615, Policy=0.0177, Value=166.9925
# [PPO] Epoch 30: Loss=79.1165, Policy=0.0132, Value=158.3118
# Approx KL Learned: 0.02546551451086998
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 5/50 — steps: 4096
# [PPO] Epoch 0: Loss=91.6882, Policy=0.0118, Value=183.4582
# [PPO] Epoch 10: Loss=85.6471, Policy=0.0173, Value=171.3651
# [PPO] Epoch 20: Loss=79.8426, Policy=0.0236, Value=159.7433
# [PPO] Epoch 30: Loss=75.8507, Policy=0.0195, Value=151.7678
# Approx KL Learned: 0.028599100187420845
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 6/50 — steps: 4096
# [PPO] Epoch 0: Loss=98.2397, Policy=0.0131, Value=196.5583
# [PPO] Epoch 10: Loss=94.1727, Policy=0.0145, Value=188.4218
# [PPO] Epoch 20: Loss=88.8582, Policy=0.0189, Value=177.7840
# [PPO] Epoch 30: Loss=83.0824, Policy=0.0162, Value=166.2380
# Approx KL Learned: 0.027748282998800278
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 7/50 — steps: 4096
# [PPO] Epoch 0: Loss=111.5736, Policy=0.0142, Value=223.2241
# [PPO] Epoch 10: Loss=96.5564, Policy=0.0285, Value=193.1610
# [PPO] Epoch 20: Loss=87.8418, Policy=0.0237, Value=175.7415
# [PPO] Epoch 30: Loss=81.9291, Policy=0.0192, Value=163.9247
# Approx KL Learned: 0.029854172840714455
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 8/50 — steps: 4096
# [PPO] Epoch 0: Loss=91.4907, Policy=0.0076, Value=183.0699
# [PPO] Epoch 10: Loss=84.1688, Policy=0.0139, Value=168.4133
# [PPO] Epoch 20: Loss=78.1055, Policy=0.0082, Value=156.2980
# [PPO] Epoch 30: Loss=73.1427, Policy=0.0160, Value=146.3582
# Approx KL Learned: 0.022502517327666283
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 9/50 — steps: 4096
# [PPO] Epoch 0: Loss=83.1835, Policy=0.0088, Value=166.4556
# [PPO] Epoch 10: Loss=77.8406, Policy=0.0078, Value=155.7715
# [PPO] Epoch 20: Loss=72.3484, Policy=0.0077, Value=144.7870
# [PPO] Epoch 30: Loss=67.2939, Policy=0.0107, Value=134.6715
# Approx KL Learned: 0.02534932643175125
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding_9.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 10/50 — steps: 4096
# [PPO] Epoch 0: Loss=88.1487, Policy=0.0079, Value=176.3866
# [PPO] Epoch 10: Loss=81.9835, Policy=0.0092, Value=164.0540
# [PPO] Epoch 20: Loss=73.7617, Policy=0.0128, Value=147.6028
# [PPO] Epoch 30: Loss=68.8743, Policy=0.0142, Value=137.8259
# Approx KL Learned: 0.04165027663111687
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 11/50 — steps: 4096
# [PPO] Epoch 0: Loss=84.7541, Policy=0.0067, Value=169.6010
# [PPO] Epoch 10: Loss=79.1187, Policy=0.0079, Value=158.3279
# [PPO] Epoch 20: Loss=76.9333, Policy=0.0059, Value=153.9612
# [PPO] Epoch 30: Loss=73.3541, Policy=0.0112, Value=146.7918
# Approx KL Learned: 0.023935018107295036
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 12/50 — steps: 4096
# [PPO] Epoch 0: Loss=93.4615, Policy=0.0147, Value=186.9992
# [PPO] Epoch 10: Loss=85.1012, Policy=0.0136, Value=170.2809
# [PPO] Epoch 20: Loss=78.4927, Policy=0.0139, Value=157.0632
# [PPO] Epoch 30: Loss=72.6181, Policy=0.0166, Value=145.3085
# Approx KL Learned: 0.022679999470710754
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 13/50 — steps: 4096
# [PPO] Epoch 0: Loss=71.2032, Policy=0.0080, Value=142.4950
# [PPO] Epoch 10: Loss=67.8583, Policy=0.0049, Value=135.8107
# [PPO] Epoch 20: Loss=63.9553, Policy=0.0079, Value=127.9982
# [PPO] Epoch 30: Loss=61.1601, Policy=0.0078, Value=122.4081
# Approx KL Learned: 0.01798984780907631
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 14/50 — steps: 4096
# [PPO] Epoch 0: Loss=63.9200, Policy=0.0113, Value=127.9213
# [PPO] Epoch 10: Loss=59.5075, Policy=0.0131, Value=119.0930
# [PPO] Epoch 20: Loss=54.9876, Policy=0.0139, Value=110.0517
# [PPO] Epoch 30: Loss=51.1234, Policy=0.0145, Value=102.3229
# Approx KL Learned: 0.023157184943556786
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 15/50 — steps: 4096
# [PPO] Epoch 0: Loss=71.3536, Policy=0.0098, Value=142.7928
# [PPO] Epoch 10: Loss=67.7652, Policy=0.0049, Value=135.6255
# [PPO] Epoch 20: Loss=62.9882, Policy=0.0054, Value=126.0705
# [PPO] Epoch 30: Loss=59.2208, Policy=0.0043, Value=118.5376
# Approx KL Learned: 0.018467213958501816
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 16/50 — steps: 4096
# [PPO] Epoch 0: Loss=68.8869, Policy=0.0050, Value=137.8669
# [PPO] Epoch 10: Loss=65.7245, Policy=0.0007, Value=131.5500
# [PPO] Epoch 20: Loss=60.7727, Policy=0.0036, Value=121.6397
# [PPO] Epoch 30: Loss=55.5123, Policy=0.0060, Value=111.1136
# Approx KL Learned: 0.029313571751117706
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 17/50 — steps: 4096
# [PPO] Epoch 0: Loss=73.8574, Policy=0.0103, Value=147.7967
# [PPO] Epoch 10: Loss=69.7548, Policy=0.0099, Value=139.5923
# [PPO] Epoch 20: Loss=64.1048, Policy=0.0085, Value=128.2945
# [PPO] Epoch 30: Loss=59.3796, Policy=0.0119, Value=118.8372
# Approx KL Learned: 0.019745245575904846
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 18/50 — steps: 4096
# [PPO] Epoch 0: Loss=109.7797, Policy=0.0090, Value=219.6429
# [PPO] Epoch 10: Loss=95.3916, Policy=0.0130, Value=190.8579
# [PPO] Epoch 20: Loss=81.3806, Policy=0.0174, Value=162.8273
# [PPO] Epoch 30: Loss=72.5649, Policy=0.0240, Value=145.1840
# Approx KL Learned: 0.035830847918987274
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 19/50 — steps: 4096
# [PPO] Epoch 0: Loss=86.5890, Policy=0.0054, Value=173.2712
# [PPO] Epoch 10: Loss=82.9264, Policy=0.0040, Value=165.9484
# [PPO] Epoch 20: Loss=75.2963, Policy=0.0074, Value=150.6814
# [PPO] Epoch 30: Loss=68.4225, Policy=0.0155, Value=136.9179
# Approx KL Learned: 0.02972773090004921
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding_19.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 20/50 — steps: 4096
# [PPO] Epoch 0: Loss=78.6284, Policy=0.0093, Value=157.3419
# [PPO] Epoch 10: Loss=74.1585, Policy=0.0169, Value=148.3868
# [PPO] Epoch 20: Loss=80.6854, Policy=0.0249, Value=161.4249
# [PPO] Epoch 30: Loss=64.2527, Policy=0.0112, Value=128.5867
# Approx KL Learned: 0.024350561201572418
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 21/50 — steps: 4096
# [PPO] Epoch 0: Loss=83.4631, Policy=0.0068, Value=167.0164
# [PPO] Epoch 10: Loss=76.1400, Policy=0.0094, Value=152.3645
# [PPO] Epoch 20: Loss=69.4215, Policy=0.0159, Value=138.9150
# [PPO] Epoch 30: Loss=63.9706, Policy=0.0175, Value=128.0102
# Approx KL Learned: 0.02590707316994667
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 22/50 — steps: 4096
# [PPO] Epoch 0: Loss=81.7217, Policy=0.0085, Value=163.5291
# [PPO] Epoch 10: Loss=66.3843, Policy=0.0133, Value=132.8426
# [PPO] Epoch 20: Loss=53.4805, Policy=0.0190, Value=107.0223
# [PPO] Epoch 30: Loss=48.6912, Policy=0.0207, Value=97.4407
# Approx KL Learned: 0.027681292966008186
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 23/50 — steps: 4096
# [PPO] Epoch 0: Loss=71.2036, Policy=0.0093, Value=142.4911
# [PPO] Epoch 10: Loss=64.0899, Policy=0.0083, Value=128.2663
# [PPO] Epoch 20: Loss=56.8257, Policy=0.0134, Value=113.7276
# [PPO] Epoch 30: Loss=49.0458, Policy=0.0091, Value=98.1759
# Approx KL Learned: 0.026788851246237755
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 24/50 — steps: 4096
# [PPO] Epoch 0: Loss=84.5490, Policy=0.0093, Value=169.1808
# [PPO] Epoch 10: Loss=80.5583, Policy=0.0127, Value=161.1928
# [PPO] Epoch 20: Loss=71.9899, Policy=0.0131, Value=144.0553
# [PPO] Epoch 30: Loss=63.7600, Policy=0.0093, Value=127.6033
# Approx KL Learned: 0.02708909660577774
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 25/50 — steps: 4096
# [PPO] Epoch 0: Loss=65.0467, Policy=0.0104, Value=130.1741
# [PPO] Epoch 10: Loss=60.2367, Policy=0.0126, Value=120.5482
# [PPO] Epoch 20: Loss=54.0517, Policy=0.0137, Value=108.1762
# [PPO] Epoch 30: Loss=48.2113, Policy=0.0171, Value=96.4889
# Approx KL Learned: 0.02790107950568199
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 26/50 — steps: 4096
# [PPO] Epoch 0: Loss=82.3674, Policy=0.0112, Value=164.8135
# [PPO] Epoch 10: Loss=73.2736, Policy=0.0113, Value=146.6246
# [PPO] Epoch 20: Loss=64.4151, Policy=0.0133, Value=128.9043
# [PPO] Epoch 30: Loss=57.0188, Policy=0.0130, Value=114.1136
# Approx KL Learned: 0.029450517147779465
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 27/50 — steps: 4096
# [PPO] Epoch 0: Loss=72.6985, Policy=0.0120, Value=145.4747
# [PPO] Epoch 10: Loss=65.6881, Policy=0.0098, Value=131.4567
# [PPO] Epoch 20: Loss=56.4689, Policy=0.0133, Value=113.0122
# [PPO] Epoch 30: Loss=51.7641, Policy=0.0147, Value=103.6007
# Approx KL Learned: 0.018419494852423668
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 28/50 — steps: 4096
# [PPO] Epoch 0: Loss=89.5526, Policy=0.0072, Value=179.1911
# [PPO] Epoch 10: Loss=78.6207, Policy=0.0061, Value=157.3276
# [PPO] Epoch 20: Loss=67.1840, Policy=0.0142, Value=134.4373
# [PPO] Epoch 30: Loss=60.4964, Policy=0.0132, Value=121.0658
# Approx KL Learned: 0.04090188443660736
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 29/50 — steps: 4096
# [PPO] Epoch 0: Loss=97.9204, Policy=0.0114, Value=195.9192
# [PPO] Epoch 10: Loss=81.3687, Policy=0.0079, Value=162.8223
# [PPO] Epoch 20: Loss=71.3251, Policy=0.0096, Value=142.7320
# [PPO] Epoch 30: Loss=62.5182, Policy=0.0205, Value=125.0975
# Approx KL Learned: 0.037586867809295654
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding_29.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 30/50 — steps: 4096
# [PPO] Epoch 0: Loss=65.9258, Policy=0.0096, Value=131.9329
# [PPO] Epoch 10: Loss=55.0855, Policy=0.0153, Value=110.2420
# [PPO] Epoch 20: Loss=48.0883, Policy=0.0238, Value=96.2316
# [PPO] Epoch 30: Loss=43.9708, Policy=0.0198, Value=88.0046
# Approx KL Learned: 0.026471106335520744
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 31/50 — steps: 4096
# [PPO] Epoch 0: Loss=98.4113, Policy=0.0091, Value=196.9082
# [PPO] Epoch 10: Loss=93.3890, Policy=0.0064, Value=186.8685
# [PPO] Epoch 20: Loss=85.7191, Policy=0.0039, Value=171.5333
# [PPO] Epoch 30: Loss=80.7461, Policy=0.0070, Value=161.5806
# Approx KL Learned: 0.023812830448150635
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 32/50 — steps: 4096
# [PPO] Epoch 0: Loss=86.4616, Policy=0.0079, Value=173.0063
# [PPO] Epoch 10: Loss=82.6816, Policy=0.0071, Value=165.4478
# [PPO] Epoch 20: Loss=78.2584, Policy=0.0118, Value=156.5926
# [PPO] Epoch 30: Loss=75.6999, Policy=0.0165, Value=151.4666
# Approx KL Learned: 0.02534436620771885
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 33/50 — steps: 4096
# [PPO] Epoch 0: Loss=73.2585, Policy=0.0120, Value=146.5912
# [PPO] Epoch 10: Loss=67.9290, Policy=0.0077, Value=135.9406
# [PPO] Epoch 20: Loss=64.9521, Policy=0.0111, Value=129.9799
# [PPO] Epoch 30: Loss=60.5198, Policy=0.0094, Value=121.1192
# Approx KL Learned: 0.02175852656364441
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 34/50 — steps: 4096
# [PPO] Epoch 0: Loss=80.7743, Policy=0.0084, Value=161.6313
# [PPO] Epoch 10: Loss=71.1296, Policy=0.0096, Value=142.3396
# [PPO] Epoch 20: Loss=68.0071, Policy=0.0162, Value=136.0821
# [PPO] Epoch 30: Loss=64.8446, Policy=0.0130, Value=129.7639
# Approx KL Learned: 0.024645984172821045
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 35/50 — steps: 4096
# [PPO] Epoch 0: Loss=82.5023, Policy=0.0074, Value=165.0927
# [PPO] Epoch 10: Loss=74.8420, Policy=0.0111, Value=149.7645
# [PPO] Epoch 20: Loss=64.3285, Policy=0.0122, Value=128.7332
# [PPO] Epoch 30: Loss=57.3666, Policy=0.0179, Value=114.7984
# Approx KL Learned: 0.040408410131931305
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 36/50 — steps: 4096
# [PPO] Epoch 0: Loss=74.4840, Policy=0.0100, Value=149.0493
# [PPO] Epoch 10: Loss=66.6546, Policy=0.0150, Value=133.3794
# [PPO] Epoch 20: Loss=59.4382, Policy=0.0174, Value=118.9421
# [PPO] Epoch 30: Loss=55.1672, Policy=0.0216, Value=110.3926
# Approx KL Learned: 0.025077281519770622
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 37/50 — steps: 4096
# [PPO] Epoch 0: Loss=84.0090, Policy=0.0073, Value=168.1037
# [PPO] Epoch 10: Loss=74.9570, Policy=0.0119, Value=149.9877
# [PPO] Epoch 20: Loss=66.3075, Policy=0.0123, Value=132.6898
# [PPO] Epoch 30: Loss=59.1465, Policy=0.0162, Value=118.3615
# Approx KL Learned: 0.029554804787039757
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 38/50 — steps: 4096
# [PPO] Epoch 0: Loss=85.8699, Policy=0.0111, Value=171.8199
# [PPO] Epoch 10: Loss=70.4550, Policy=0.0126, Value=140.9872
# [PPO] Epoch 20: Loss=58.4983, Policy=0.0172, Value=117.0642
# [PPO] Epoch 30: Loss=50.8347, Policy=0.0220, Value=101.7284
# Approx KL Learned: 0.02896529622375965
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 39/50 — steps: 4096
# [PPO] Epoch 0: Loss=74.1310, Policy=0.0117, Value=148.3417
# [PPO] Epoch 10: Loss=67.1319, Policy=0.0138, Value=134.3383
# [PPO] Epoch 20: Loss=58.1579, Policy=0.0245, Value=116.3665
# [PPO] Epoch 30: Loss=50.0212, Policy=0.0232, Value=100.0964
# Approx KL Learned: 0.026808785274624825
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding_39.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 40/50 — steps: 4096
# [PPO] Epoch 0: Loss=73.2355, Policy=0.0108, Value=146.5519
# [PPO] Epoch 10: Loss=57.4503, Policy=0.0120, Value=114.9782
# [PPO] Epoch 20: Loss=54.1449, Policy=0.0162, Value=108.3592
# [PPO] Epoch 30: Loss=49.9677, Policy=0.0161, Value=100.0052
# Approx KL Learned: 0.027613546699285507
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 41/50 — steps: 4096
# [PPO] Epoch 0: Loss=71.5184, Policy=0.0092, Value=143.1187
# [PPO] Epoch 10: Loss=64.1094, Policy=0.0066, Value=128.3046
# [PPO] Epoch 20: Loss=56.5678, Policy=0.0117, Value=113.2128
# [PPO] Epoch 30: Loss=50.3843, Policy=0.0215, Value=100.8271
# Approx KL Learned: 0.017279352992773056
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 42/50 — steps: 4096
# [PPO] Epoch 0: Loss=69.0551, Policy=0.0092, Value=138.1921
# [PPO] Epoch 10: Loss=60.7865, Policy=0.0095, Value=121.6528
# [PPO] Epoch 20: Loss=52.4501, Policy=0.0087, Value=104.9812
# [PPO] Epoch 30: Loss=45.1565, Policy=0.0108, Value=90.3907
# Approx KL Learned: 0.02861860580742359
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 43/50 — steps: 4096
# [PPO] Epoch 0: Loss=72.5704, Policy=0.0100, Value=145.2185
# [PPO] Epoch 10: Loss=60.6507, Policy=0.0138, Value=121.3709
# [PPO] Epoch 20: Loss=52.4204, Policy=0.0262, Value=104.8859
# [PPO] Epoch 30: Loss=45.5677, Policy=0.0296, Value=91.1746
# Approx KL Learned: 0.03243108093738556
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 44/50 — steps: 4096
# [PPO] Epoch 0: Loss=85.4238, Policy=0.0113, Value=170.9261
# [PPO] Epoch 10: Loss=72.2828, Policy=0.0133, Value=144.6403
# [PPO] Epoch 20: Loss=60.8758, Policy=0.0157, Value=121.8204
# [PPO] Epoch 30: Loss=54.2435, Policy=0.0110, Value=108.5660
# Approx KL Learned: 0.03314308822154999
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 45/50 — steps: 4096
# [PPO] Epoch 0: Loss=97.5912, Policy=0.0115, Value=195.2612
# [PPO] Epoch 10: Loss=90.1855, Policy=0.0115, Value=180.4496
# [PPO] Epoch 20: Loss=79.2812, Policy=0.0132, Value=158.6360
# [PPO] Epoch 30: Loss=72.0110, Policy=0.0135, Value=144.0950
# Approx KL Learned: 0.028556296601891518
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 46/50 — steps: 4096
# [PPO] Epoch 0: Loss=84.0025, Policy=0.0096, Value=168.0864
# [PPO] Epoch 10: Loss=75.7967, Policy=0.0109, Value=151.6717
# [PPO] Epoch 20: Loss=67.4773, Policy=0.0171, Value=135.0191
# [PPO] Epoch 30: Loss=60.9854, Policy=0.0204, Value=122.0289
# Approx KL Learned: 0.03559941053390503
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 47/50 — steps: 4096
# [PPO] Epoch 0: Loss=74.3987, Policy=0.0069, Value=148.8829
# [PPO] Epoch 10: Loss=66.0888, Policy=0.0072, Value=132.2629
# [PPO] Epoch 20: Loss=57.6327, Policy=0.0086, Value=115.3482
# [PPO] Epoch 30: Loss=49.3401, Policy=0.0154, Value=98.7502
# Approx KL Learned: 0.033393412828445435
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 48/50 — steps: 4096
# [PPO] Epoch 0: Loss=79.8996, Policy=0.0116, Value=159.8777
# [PPO] Epoch 10: Loss=69.6677, Policy=0.0127, Value=139.4114
# [PPO] Epoch 20: Loss=59.9658, Policy=0.0169, Value=119.9990
# [PPO] Epoch 30: Loss=50.6279, Policy=0.0207, Value=101.3162
# Approx KL Learned: 0.02386731654405594
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 49/50 — steps: 4096
# [PPO] Epoch 0: Loss=88.6304, Policy=0.0109, Value=177.3407
# [PPO] Epoch 10: Loss=76.3520, Policy=0.0136, Value=152.7780
# [PPO] Epoch 20: Loss=70.5168, Policy=0.0216, Value=141.0912
# [PPO] Epoch 30: Loss=68.1299, Policy=0.0192, Value=136.3225
# Approx KL Learned: 0.024390049278736115
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding_49.pt
# [✅] Actor-Critic checkpoint saved to data/pca_resnet_sliding.pt
# Update 50/50 — steps: 4096
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>▁▂▃▃▅▃▅▃▇▄▇▆█▅▄▄▅▆▆▅█▅▅▇▇▇▆▆▆▃▆▆▆▅▆▅▅▇▆▅</td></tr><tr><td>reward</td><td>▂▂▂▃▃▄▄▅▄▅▃▄▃▇█▃▁▄▄▄▄▂▂▂▂▇▂▂▅█▅▄▄▂▂▆▃█▆▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>episode_reward</td><td>0.22418</td></tr><tr><td>reward</td><td>0.01609</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pca_resnet_sliding</strong> at: <a href='https://wandb.ai/viriyadhika1/cv-final-project/runs/ar37e0m0' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project/runs/ar37e0m0</a><br> View project at: <a href='https://wandb.ai/viriyadhika1/cv-final-project' target="_blank">https://wandb.ai/viriyadhika1/cv-final-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251125_182752-ar37e0m0/logs</code>
# (<rl.RolloutBuffer at 0x7f85ce3b7a10>, [], [])
